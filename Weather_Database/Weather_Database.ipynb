# %%
# Import the random module.
import random

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# (Step 3) Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module.
from citipy import citipy

# %%
# (Step 4) Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
city
# Out:
# 'saskylakh'

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 753

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# (Step 5) Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e5437bdbf0f856a34296c9a6e740f787

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e5437bdbf0f856a34296c9a6e740f787&q=Boston

# %%
# (Step 6) Loop through all the cities in the list and use for-except to work around potential

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.    
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Descripion" : city_desc,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | luwuk
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | airai
# Processing Record 7 of Set 1 | itupiranga
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | maragogi
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | bredasdorp
# Processing Record 13 of Set 1 | kodiak
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | constitucion
# Processing Record 16 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 17 of Set 1 | santa isabel
# Processing Record 18 of Set 1 | roma
# Processing Record 19 of Set 1 | balabac
# Processing Record 20 of Set 1 | cape town
# Processing Record 21 of Set 1 | provideniya
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | shiyan
# Processing Record 24 of Set 1 | valle de allende
# Processing Record 25 of Set 1 | andreapol
# Processing Record 26 of Set 1 | lebu
# Processing Record 27 of Set 1 | punta arenas
# Processing Record 28 of Set 1 | santa vitoria do palmar
# Processing Record 29 of Set 1 | caohai
# Processing Record 30 of Set 1 | guerrero negro
# Processing Record 31 of Set 1 | margate
# Processing Record 32 of Set 1 | hithadhoo
# Processing Record 33 of Set 1 | alice springs
# Processing Record 34 of Set 1 | pontianak
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | college
# Processing Record 38 of Set 1 | traverse city
# Processing Record 39 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 40 of Set 1 | popondetta
# Processing Record 41 of Set 1 | saskylakh
# Processing Record 42 of Set 1 | bambous virieux
# Processing Record 43 of Set 1 | sitka
# Processing Record 44 of Set 1 | mahebourg
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | east london
# Processing Record 48 of Set 1 | sao filipe
# Processing Record 49 of Set 1 | arraial do cabo
# Processing Record 50 of Set 1 | bolu
# Processing Record 1 of Set 2 | srednekolymsk
# Processing Record 2 of Set 2 | richards bay
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | saint-francois
# Processing Record 5 of Set 2 | kaitangata
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | mgachi
# Processing Record 9 of Set 2 | iquitos
# Processing Record 10 of Set 2 | cheuskiny
# City not found. Skipping...
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | tasiilaq
# Processing Record 13 of Set 2 | laguna de duero
# Processing Record 14 of Set 2 | lavrentiya
# Processing Record 15 of Set 2 | monte aprazivel
# Processing Record 16 of Set 2 | aksu
# Processing Record 17 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 2 | myaundzha
# Processing Record 19 of Set 2 | isiro
# Processing Record 20 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 21 of Set 2 | clyde river
# Processing Record 22 of Set 2 | saint-augustin
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | rikitea
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | wawa
# Processing Record 28 of Set 2 | grand gaube
# Processing Record 29 of Set 2 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 2 | yurimaguas
# Processing Record 31 of Set 2 | ahuimanu
# Processing Record 32 of Set 2 | bera
# Processing Record 33 of Set 2 | hualmay
# Processing Record 34 of Set 2 | tessalit
# Processing Record 35 of Set 2 | griffith
# Processing Record 36 of Set 2 | port elizabeth
# Processing Record 37 of Set 2 | kattivakkam
# Processing Record 38 of Set 2 | kahului
# Processing Record 39 of Set 2 | lompoc
# Processing Record 40 of Set 2 | loncoche
# Processing Record 41 of Set 2 | lorengau
# Processing Record 42 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 43 of Set 2 | saint-philippe
# Processing Record 44 of Set 2 | sidi ali
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | meulaboh
# Processing Record 47 of Set 2 | bethel
# Processing Record 48 of Set 2 | aiken
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | mar del plata
# Processing Record 1 of Set 3 | christchurch
# Processing Record 2 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 3 | ossora
# Processing Record 4 of Set 3 | petrozavodsk
# Processing Record 5 of Set 3 | manokwari
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | avera
# Processing Record 8 of Set 3 | bandarbeyla
# Processing Record 9 of Set 3 | vavuniya
# Processing Record 10 of Set 3 | kalmunai
# Processing Record 11 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 3 | jamestown
# Processing Record 13 of Set 3 | pevek
# Processing Record 14 of Set 3 | san cristobal
# Processing Record 15 of Set 3 | upernavik
# Processing Record 16 of Set 3 | port alfred
# Processing Record 17 of Set 3 | san policarpo
# Processing Record 18 of Set 3 | leningradskiy
# Processing Record 19 of Set 3 | ravar
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | santa isabel do rio negro
# Processing Record 24 of Set 3 | qinzhou
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | yellowknife
# Processing Record 28 of Set 3 | champua
# Processing Record 29 of Set 3 | dudinka
# Processing Record 30 of Set 3 | saint george
# Processing Record 31 of Set 3 | polson
# Processing Record 32 of Set 3 | ust-maya
# Processing Record 33 of Set 3 | gazli
# Processing Record 34 of Set 3 | carnarvon
# Processing Record 35 of Set 3 | port hawkesbury
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | la ronge
# Processing Record 38 of Set 3 | vicksburg
# Processing Record 39 of Set 3 | san ignacio
# Processing Record 40 of Set 3 | kavieng
# Processing Record 41 of Set 3 | roald
# Processing Record 42 of Set 3 | puerto ayora
# Processing Record 43 of Set 3 | bluff
# Processing Record 44 of Set 3 | sidney
# Processing Record 45 of Set 3 | talara
# Processing Record 46 of Set 3 | bitkine
# Processing Record 47 of Set 3 | wanning
# Processing Record 48 of Set 3 | faanui
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | berlevag
# Processing Record 1 of Set 4 | pilar
# Processing Record 2 of Set 4 | gravdal
# Processing Record 3 of Set 4 | port blair
# Processing Record 4 of Set 4 | ribeira grande
# Processing Record 5 of Set 4 | upata
# Processing Record 6 of Set 4 | torbay
# Processing Record 7 of Set 4 | state college
# Processing Record 8 of Set 4 | colares
# Processing Record 9 of Set 4 | dunedin
# Processing Record 10 of Set 4 | coahuayana
# Processing Record 11 of Set 4 | namibe
# Processing Record 12 of Set 4 | barreirinha
# Processing Record 13 of Set 4 | kroya
# Processing Record 14 of Set 4 | sorong
# Processing Record 15 of Set 4 | athabasca
# Processing Record 16 of Set 4 | kazachinskoye
# Processing Record 17 of Set 4 | atuona
# Processing Record 18 of Set 4 | lhokseumawe
# Processing Record 19 of Set 4 | jati
# Processing Record 20 of Set 4 | santa maria
# Processing Record 21 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 4 | baykalovo
# Processing Record 23 of Set 4 | saint-joseph
# Processing Record 24 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 4 | bowen
# Processing Record 26 of Set 4 | fomboni
# Processing Record 27 of Set 4 | mbandaka
# Processing Record 28 of Set 4 | sobolevo
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | san agustin
# Processing Record 31 of Set 4 | gushikawa
# Processing Record 32 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 33 of Set 4 | nome
# Processing Record 34 of Set 4 | ituni
# City not found. Skipping...
# Processing Record 35 of Set 4 | leshukonskoye
# Processing Record 36 of Set 4 | ondjiva
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | tawang
# Processing Record 39 of Set 4 | jinxi
# Processing Record 40 of Set 4 | bystryy istok
# Processing Record 41 of Set 4 | souillac
# Processing Record 42 of Set 4 | barcelos
# Processing Record 43 of Set 4 | marawi
# Processing Record 44 of Set 4 | qurbah
# City not found. Skipping...
# Processing Record 45 of Set 4 | shache
# Processing Record 46 of Set 4 | ponta do sol
# Processing Record 47 of Set 4 | hay river
# Processing Record 48 of Set 4 | caravelas
# Processing Record 49 of Set 4 | vranovice
# Processing Record 50 of Set 4 | oranjestad
# Processing Record 1 of Set 5 | sisimiut
# Processing Record 2 of Set 5 | naruja
# Processing Record 3 of Set 5 | plouzane
# Processing Record 4 of Set 5 | ayan
# Processing Record 5 of Set 5 | songea
# Processing Record 6 of Set 5 | leh
# Processing Record 7 of Set 5 | walvis bay
# Processing Record 8 of Set 5 | leo
# Processing Record 9 of Set 5 | san patricio
# Processing Record 10 of Set 5 | chincha alta
# Processing Record 11 of Set 5 | chuy
# Processing Record 12 of Set 5 | kautokeino
# Processing Record 13 of Set 5 | isperih
# Processing Record 14 of Set 5 | castro
# Processing Record 15 of Set 5 | kuryk
# Processing Record 16 of Set 5 | iqaluit
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | anloga
# Processing Record 19 of Set 5 | vila franca do campo
# Processing Record 20 of Set 5 | mount isa
# Processing Record 21 of Set 5 | tuktoyaktuk
# Processing Record 22 of Set 5 | arroyo
# Processing Record 23 of Set 5 | praia
# Processing Record 24 of Set 5 | tubruq
# City not found. Skipping...
# Processing Record 25 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 5 | nikolskoye
# Processing Record 27 of Set 5 | port hedland
# Processing Record 28 of Set 5 | racova
# Processing Record 29 of Set 5 | nusaybin
# Processing Record 30 of Set 5 | bend
# Processing Record 31 of Set 5 | alofi
# Processing Record 32 of Set 5 | broken hill
# Processing Record 33 of Set 5 | teya
# Processing Record 34 of Set 5 | buala
# Processing Record 35 of Set 5 | hervey bay
# Processing Record 36 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 5 | amahai
# Processing Record 38 of Set 5 | alfonsine
# Processing Record 39 of Set 5 | progreso
# Processing Record 40 of Set 5 | scarborough
# Processing Record 41 of Set 5 | miyako
# Processing Record 42 of Set 5 | fairbanks
# Processing Record 43 of Set 5 | kununurra
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | aljezur
# Processing Record 46 of Set 5 | sabang
# Processing Record 47 of Set 5 | xining
# Processing Record 48 of Set 5 | sao jose da coroa grande
# Processing Record 49 of Set 5 | hakkari
# Processing Record 50 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 6 | klaksvik
# Processing Record 2 of Set 6 | pacific grove
# Processing Record 3 of Set 6 | sulangan
# Processing Record 4 of Set 6 | nemuro
# Processing Record 5 of Set 6 | awbari
# Processing Record 6 of Set 6 | wuchi
# Processing Record 7 of Set 6 | fuldatal
# Processing Record 8 of Set 6 | dakar
# Processing Record 9 of Set 6 | villa carlos paz
# Processing Record 10 of Set 6 | acapulco
# Processing Record 11 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 6 | baisha
# Processing Record 13 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 6 | bindura
# Processing Record 15 of Set 6 | sao joao da barra
# Processing Record 16 of Set 6 | ruwi
# Processing Record 17 of Set 6 | gaoua
# Processing Record 18 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 6 | codrington
# Processing Record 20 of Set 6 | laguna
# Processing Record 21 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 6 | atar
# Processing Record 23 of Set 6 | morristown
# Processing Record 24 of Set 6 | baiao
# Processing Record 25 of Set 6 | coihueco
# Processing Record 26 of Set 6 | cozumel
# Processing Record 27 of Set 6 | safaga
# Processing Record 28 of Set 6 | astana
# Processing Record 29 of Set 6 | qasigiannguit
# Processing Record 30 of Set 6 | inhambane
# Processing Record 31 of Set 6 | poronaysk
# Processing Record 32 of Set 6 | north highlands
# Processing Record 33 of Set 6 | faya
# Processing Record 34 of Set 6 | flinders
# Processing Record 35 of Set 6 | portsmouth
# Processing Record 36 of Set 6 | cabinda
# Processing Record 37 of Set 6 | aktau
# Processing Record 38 of Set 6 | gien
# Processing Record 39 of Set 6 | batagay-alyta
# Processing Record 40 of Set 6 | port hardy
# Processing Record 41 of Set 6 | avarua
# Processing Record 42 of Set 6 | mehamn
# Processing Record 43 of Set 6 | chynadiyovo
# Processing Record 44 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 6 | waverly
# Processing Record 46 of Set 6 | lillooet
# Processing Record 47 of Set 6 | vestmannaeyjar
# Processing Record 48 of Set 6 | bendigo
# Processing Record 49 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 50 of Set 6 | lagos
# Processing Record 1 of Set 7 | domoni
# Processing Record 2 of Set 7 | shebalino
# Processing Record 3 of Set 7 | taksimo
# Processing Record 4 of Set 7 | shitanjing
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | fare
# Processing Record 7 of Set 7 | soto la marina
# Processing Record 8 of Set 7 | biak
# Processing Record 9 of Set 7 | omboue
# Processing Record 10 of Set 7 | maputo
# Processing Record 11 of Set 7 | mpika
# Processing Record 12 of Set 7 | vilhena
# Processing Record 13 of Set 7 | binga
# Processing Record 14 of Set 7 | todos santos
# Processing Record 15 of Set 7 | mayumba
# Processing Record 16 of Set 7 | gimli
# Processing Record 17 of Set 7 | kidal
# Processing Record 18 of Set 7 | benemerito de las americas
# Processing Record 19 of Set 7 | kruisfontein
# Processing Record 20 of Set 7 | xicotencatl
# Processing Record 21 of Set 7 | uarini
# Processing Record 22 of Set 7 | katsuura
# Processing Record 23 of Set 7 | fortuna
# Processing Record 24 of Set 7 | hofn
# Processing Record 25 of Set 7 | svetlogorsk
# Processing Record 26 of Set 7 | barinitas
# Processing Record 27 of Set 7 | mitsamiouli
# Processing Record 28 of Set 7 | itarema
# Processing Record 29 of Set 7 | chirilagua
# Processing Record 30 of Set 7 | malanje
# Processing Record 31 of Set 7 | atambua
# Processing Record 32 of Set 7 | yerbogachen
# Processing Record 33 of Set 7 | karratha
# Processing Record 34 of Set 7 | port lincoln
# Processing Record 35 of Set 7 | raychikhinsk
# Processing Record 36 of Set 7 | rawson
# Processing Record 37 of Set 7 | hovd
# Processing Record 38 of Set 7 | tautira
# Processing Record 39 of Set 7 | anadyr
# Processing Record 40 of Set 7 | nouadhibou
# Processing Record 41 of Set 7 | vardo
# Processing Record 42 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 7 | vikulovo
# Processing Record 44 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 45 of Set 7 | talnakh
# Processing Record 46 of Set 7 | arkhangelos
# City not found. Skipping...
# Processing Record 47 of Set 7 | sherghati
# Processing Record 48 of Set 7 | kenai
# Processing Record 49 of Set 7 | guilin
# Processing Record 50 of Set 7 | nalut
# Processing Record 1 of Set 8 | casa nova
# Processing Record 2 of Set 8 | kaeo
# Processing Record 3 of Set 8 | biu
# Processing Record 4 of Set 8 | rio gallegos
# Processing Record 5 of Set 8 | longyearbyen
# Processing Record 6 of Set 8 | coquimbo
# Processing Record 7 of Set 8 | kasane
# Processing Record 8 of Set 8 | pauini
# Processing Record 9 of Set 8 | zapolyarnyy
# Processing Record 10 of Set 8 | bubaque
# Processing Record 11 of Set 8 | grand-santi
# Processing Record 12 of Set 8 | kassala
# Processing Record 13 of Set 8 | cabra
# Processing Record 14 of Set 8 | bahia blanca
# Processing Record 15 of Set 8 | nizhniy tsasuchey
# Processing Record 16 of Set 8 | vila
# Processing Record 17 of Set 8 | orange cove
# Processing Record 18 of Set 8 | seoul
# Processing Record 19 of Set 8 | korla
# Processing Record 20 of Set 8 | dunmore town
# Processing Record 21 of Set 8 | irece
# Processing Record 22 of Set 8 | chicama
# Processing Record 23 of Set 8 | the pas
# Processing Record 24 of Set 8 | fallon
# Processing Record 25 of Set 8 | kavaratti
# Processing Record 26 of Set 8 | makat
# Processing Record 27 of Set 8 | chik
# Processing Record 28 of Set 8 | yantal
# Processing Record 29 of Set 8 | lagoa
# Processing Record 30 of Set 8 | bondo
# Processing Record 31 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 32 of Set 8 | krasnoselkup
# Processing Record 33 of Set 8 | muravlenko
# Processing Record 34 of Set 8 | niles
# Processing Record 35 of Set 8 | zhigansk
# Processing Record 36 of Set 8 | eskasem
# City not found. Skipping...
# Processing Record 37 of Set 8 | husavik
# Processing Record 38 of Set 8 | mtimbira
# Processing Record 39 of Set 8 | raudeberg
# Processing Record 40 of Set 8 | hambantota
# Processing Record 41 of Set 8 | yumen
# Processing Record 42 of Set 8 | norman wells
# Processing Record 43 of Set 8 | honningsvag
# Processing Record 44 of Set 8 | axim
# Processing Record 45 of Set 8 | luganville
# Processing Record 46 of Set 8 | hundested
# Processing Record 47 of Set 8 | humaita
# Processing Record 48 of Set 8 | samfya
# Processing Record 49 of Set 8 | severo-kurilsk
# Processing Record 50 of Set 8 | nanortalik
# Processing Record 1 of Set 9 | horodyshche
# Processing Record 2 of Set 9 | nichinan
# Processing Record 3 of Set 9 | baruun-urt
# Processing Record 4 of Set 9 | moindou
# Processing Record 5 of Set 9 | hendaye
# Processing Record 6 of Set 9 | zeya
# Processing Record 7 of Set 9 | wewak
# Processing Record 8 of Set 9 | dingle
# Processing Record 9 of Set 9 | yatou
# Processing Record 10 of Set 9 | deniliquin
# Processing Record 11 of Set 9 | buqayq
# City not found. Skipping...
# Processing Record 12 of Set 9 | cabo san lucas
# Processing Record 13 of Set 9 | itoman
# Processing Record 14 of Set 9 | ostrovnoy
# Processing Record 15 of Set 9 | tarakan
# Processing Record 16 of Set 9 | adeje
# Processing Record 17 of Set 9 | cucutilla
# Processing Record 18 of Set 9 | hobyo
# Processing Record 19 of Set 9 | zelenoborsk
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | naze
# Processing Record 22 of Set 9 | moose factory
# Processing Record 23 of Set 9 | bolo
# Processing Record 24 of Set 9 | monte alegre
# Processing Record 25 of Set 9 | ambilobe
# Processing Record 26 of Set 9 | matagami
# Processing Record 27 of Set 9 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | kazerun
# Processing Record 29 of Set 9 | balkanabat
# Processing Record 30 of Set 9 | ouesso
# Processing Record 31 of Set 9 | bonavista
# Processing Record 32 of Set 9 | susanville
# Processing Record 33 of Set 9 | kanigoro
# Processing Record 34 of Set 9 | lafia
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | awjilah
# Processing Record 37 of Set 9 | jardim
# Processing Record 38 of Set 9 | barinas
# Processing Record 39 of Set 9 | nouakchott
# Processing Record 40 of Set 9 | ajdabiya
# Processing Record 41 of Set 9 | florin
# Processing Record 42 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 9 | kita
# Processing Record 44 of Set 9 | paamiut
# Processing Record 45 of Set 9 | newport
# Processing Record 46 of Set 9 | kaoma
# Processing Record 47 of Set 9 | nara
# Processing Record 48 of Set 9 | khvastovichi
# Processing Record 49 of Set 9 | sinkat
# City not found. Skipping...
# Processing Record 50 of Set 9 | pindi bhattian
# Processing Record 1 of Set 10 | sovetskiy
# Processing Record 2 of Set 10 | mayo
# Processing Record 3 of Set 10 | san miguel
# Processing Record 4 of Set 10 | portland
# Processing Record 5 of Set 10 | yar-sale
# Processing Record 6 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 7 of Set 10 | tura
# Processing Record 8 of Set 10 | beira
# Processing Record 9 of Set 10 | nicoya
# Processing Record 10 of Set 10 | wahran
# City not found. Skipping...
# Processing Record 11 of Set 10 | vestmanna
# Processing Record 12 of Set 10 | karasjok
# Processing Record 13 of Set 10 | cam pha
# City not found. Skipping...
# Processing Record 14 of Set 10 | komsomolskiy
# Processing Record 15 of Set 10 | ucluelet
# Processing Record 16 of Set 10 | port augusta
# Processing Record 17 of Set 10 | tondano
# Processing Record 18 of Set 10 | des moines
# Processing Record 19 of Set 10 | meiktila
# Processing Record 20 of Set 10 | hami
# Processing Record 21 of Set 10 | valparaiso
# Processing Record 22 of Set 10 | bocaranga
# City not found. Skipping...
# Processing Record 23 of Set 10 | newtownards
# Processing Record 24 of Set 10 | port moresby
# Processing Record 25 of Set 10 | rio grande
# Processing Record 26 of Set 10 | inirida
# Processing Record 27 of Set 10 | gonbad-e qabus
# Processing Record 28 of Set 10 | chokwe
# Processing Record 29 of Set 10 | adana
# Processing Record 30 of Set 10 | tiksi
# Processing Record 31 of Set 10 | bathsheba
# Processing Record 32 of Set 10 | dungarvan
# Processing Record 33 of Set 10 | encruzilhada
# Processing Record 34 of Set 10 | cumaru
# Processing Record 35 of Set 10 | novokizhinginsk
# Processing Record 36 of Set 10 | khani
# Processing Record 37 of Set 10 | mumford
# Processing Record 38 of Set 10 | rocha
# Processing Record 39 of Set 10 | esil
# Processing Record 40 of Set 10 | svetlaya
# Processing Record 41 of Set 10 | acarau
# Processing Record 42 of Set 10 | grua
# Processing Record 43 of Set 10 | toora-khem
# Processing Record 44 of Set 10 | sakiai
# Processing Record 45 of Set 10 | aykhal
# Processing Record 46 of Set 10 | honiara
# Processing Record 47 of Set 10 | yaring
# Processing Record 48 of Set 10 | salinopolis
# Processing Record 49 of Set 10 | abengourou
# Processing Record 50 of Set 10 | los llanos de aridane
# Processing Record 1 of Set 11 | oistins
# Processing Record 2 of Set 11 | muzhi
# Processing Record 3 of Set 11 | moranbah
# Processing Record 4 of Set 11 | durango
# Processing Record 5 of Set 11 | qidong
# Processing Record 6 of Set 11 | columbia
# Processing Record 7 of Set 11 | dong hoi
# Processing Record 8 of Set 11 | benicarlo
# Processing Record 9 of Set 11 | alta floresta
# Processing Record 10 of Set 11 | gazimurskiy zavod
# Processing Record 11 of Set 11 | kanalion
# Processing Record 12 of Set 11 | flin flon
# Processing Record 13 of Set 11 | leninskoye
# Processing Record 14 of Set 11 | aguimes
# Processing Record 15 of Set 11 | saint-pierre
# Processing Record 16 of Set 11 | devaprayag
# Processing Record 17 of Set 11 | prado
# Processing Record 18 of Set 11 | agar
# Processing Record 19 of Set 11 | lagunas
# Processing Record 20 of Set 11 | ilulissat
# Processing Record 21 of Set 11 | arlit
# Processing Record 22 of Set 11 | alfatar
# Processing Record 23 of Set 11 | skibbereen
# Processing Record 24 of Set 11 | barela
# Processing Record 25 of Set 11 | kewanee
# Processing Record 26 of Set 11 | vila velha
# Processing Record 27 of Set 11 | livingston
# Processing Record 28 of Set 11 | riyadh
# Processing Record 29 of Set 11 | katangli
# Processing Record 30 of Set 11 | hasaki
# Processing Record 31 of Set 11 | jaen
# Processing Record 32 of Set 11 | prince rupert
# Processing Record 33 of Set 11 | ancud
# Processing Record 34 of Set 11 | eureka
# Processing Record 35 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 36 of Set 11 | deputatskiy
# Processing Record 37 of Set 11 | tuni
# Processing Record 38 of Set 11 | ginda
# Processing Record 39 of Set 11 | tilichiki
# Processing Record 40 of Set 11 | el dorado
# Processing Record 41 of Set 11 | tumpat
# Processing Record 42 of Set 11 | porto novo
# Processing Record 43 of Set 11 | lalsot
# Processing Record 44 of Set 11 | erbaa
# Processing Record 45 of Set 11 | naryan-mar
# Processing Record 46 of Set 11 | krasnoarmeysk
# Processing Record 47 of Set 11 | laurel
# Processing Record 48 of Set 11 | finschhafen
# Processing Record 49 of Set 11 | vallenar
# Processing Record 50 of Set 11 | nioro
# Processing Record 1 of Set 12 | agadez
# Processing Record 2 of Set 12 | labuhan
# Processing Record 3 of Set 12 | sakyla
# Processing Record 4 of Set 12 | buturlino
# Processing Record 5 of Set 12 | tianpeng
# Processing Record 6 of Set 12 | hamilton
# Processing Record 7 of Set 12 | dongsheng
# Processing Record 8 of Set 12 | aklavik
# Processing Record 9 of Set 12 | goderich
# Processing Record 10 of Set 12 | gopalpur
# Processing Record 11 of Set 12 | bad harzburg
# Processing Record 12 of Set 12 | margherita
# Processing Record 13 of Set 12 | sioux lookout
# Processing Record 14 of Set 12 | winnemucca
# Processing Record 15 of Set 12 | ouango
# Processing Record 16 of Set 12 | odolena voda
# Processing Record 17 of Set 12 | yoichi
# Processing Record 18 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 19 of Set 12 | beringovskiy
# Processing Record 20 of Set 12 | saint cloud
# Processing Record 21 of Set 12 | ambulu
# Processing Record 22 of Set 12 | bambanglipuro
# Processing Record 23 of Set 12 | antalaha
# Processing Record 24 of Set 12 | santa clara
# Processing Record 25 of Set 12 | xudat
# Processing Record 26 of Set 12 | turan
# Processing Record 27 of Set 12 | galiwinku
# City not found. Skipping...
# Processing Record 28 of Set 12 | ailigandi
# Processing Record 29 of Set 12 | igarka
# Processing Record 30 of Set 12 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 31 of Set 12 | iracoubo
# Processing Record 32 of Set 12 | nador
# Processing Record 33 of Set 12 | bardiyah
# Processing Record 34 of Set 12 | wadi maliz
# Processing Record 35 of Set 12 | alyangula
# Processing Record 36 of Set 12 | mpanda
# Processing Record 37 of Set 12 | oktyabrskiy
# Processing Record 38 of Set 12 | usinsk
# Processing Record 39 of Set 12 | chingirlau
# Processing Record 40 of Set 12 | port hueneme
# Processing Record 41 of Set 12 | norden
# Processing Record 42 of Set 12 | mata
# Processing Record 43 of Set 12 | kamaishi
# Processing Record 44 of Set 12 | povorino
# Processing Record 45 of Set 12 | palmas bellas
# Processing Record 46 of Set 12 | kitui
# Processing Record 47 of Set 12 | puerto leguizamo
# Processing Record 48 of Set 12 | fangshan
# Processing Record 49 of Set 12 | dawlatabad
# Processing Record 50 of Set 12 | along
# Processing Record 1 of Set 13 | kaabong
# Processing Record 2 of Set 13 | riverton
# Processing Record 3 of Set 13 | saryg-sep
# Processing Record 4 of Set 13 | shieli
# Processing Record 5 of Set 13 | poum
# Processing Record 6 of Set 13 | sangar
# Processing Record 7 of Set 13 | marfino
# Processing Record 8 of Set 13 | bagdarin
# Processing Record 9 of Set 13 | katy
# Processing Record 10 of Set 13 | asau
# Processing Record 11 of Set 13 | elko
# Processing Record 12 of Set 13 | llanes
# Processing Record 13 of Set 13 | kathu
# Processing Record 14 of Set 13 | san quintin
# Processing Record 15 of Set 13 | krasavino
# Processing Record 16 of Set 13 | dukat
# Processing Record 17 of Set 13 | kargasok
# Processing Record 18 of Set 13 | wittmund
# Processing Record 19 of Set 13 | cedar city
# Processing Record 20 of Set 13 | quelimane
# Processing Record 21 of Set 13 | gilgit
# Processing Record 22 of Set 13 | conceicao da barra
# Processing Record 23 of Set 13 | khasan
# Processing Record 24 of Set 13 | hyeres
# Processing Record 25 of Set 13 | basoko
# Processing Record 26 of Set 13 | lethem
# Processing Record 27 of Set 13 | bairnsdale
# Processing Record 28 of Set 13 | alford
# Processing Record 29 of Set 13 | taoudenni
# Processing Record 30 of Set 13 | belaya gora
# Processing Record 31 of Set 13 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 13 | pisco
# Processing Record 33 of Set 13 | ukiah
# Processing Record 34 of Set 13 | kasongo-lunda
# Processing Record 35 of Set 13 | garowe
# Processing Record 36 of Set 13 | malanville
# Processing Record 37 of Set 13 | abu kamal
# Processing Record 38 of Set 13 | ayutla
# Processing Record 39 of Set 13 | pangnirtung
# Processing Record 40 of Set 13 | palencia
# Processing Record 41 of Set 13 | namatanai
# Processing Record 42 of Set 13 | horta
# Processing Record 43 of Set 13 | mathbaria
# Processing Record 44 of Set 13 | coihaique
# Processing Record 45 of Set 13 | sinnamary
# Processing Record 46 of Set 13 | huicungo
# Processing Record 47 of Set 13 | semenivka
# Processing Record 48 of Set 13 | llandrindod wells
# Processing Record 49 of Set 13 | san joaquin
# Processing Record 50 of Set 13 | padang
# Processing Record 1 of Set 14 | ivybridge
# Processing Record 2 of Set 14 | eyl
# Processing Record 3 of Set 14 | tromso
# Processing Record 4 of Set 14 | kigoma
# Processing Record 5 of Set 14 | pohrebyshche
# Processing Record 6 of Set 14 | najran
# Processing Record 7 of Set 14 | henties bay
# Processing Record 8 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 9 of Set 14 | carrara
# Processing Record 10 of Set 14 | zhelyabovka
# Processing Record 11 of Set 14 | gamba
# Processing Record 12 of Set 14 | chapada dos guimaraes
# Processing Record 13 of Set 14 | srivardhan
# Processing Record 14 of Set 14 | tokur
# Processing Record 15 of Set 14 | tutoia
# Processing Record 16 of Set 14 | kichera
# Processing Record 17 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 18 of Set 14 | tadine
# Processing Record 19 of Set 14 | praya
# Processing Record 20 of Set 14 | nizhniy kuranakh
# Processing Record 21 of Set 14 | mount gambier
# Processing Record 22 of Set 14 | cap malheureux
# Processing Record 23 of Set 14 | yeppoon
# Processing Record 24 of Set 14 | poltavka
# Processing Record 25 of Set 14 | hamada
# Processing Record 26 of Set 14 | san francisco
# Processing Record 27 of Set 14 | meiganga
# Processing Record 28 of Set 14 | adrar
# Processing Record 29 of Set 14 | acajutla
# Processing Record 30 of Set 14 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 14 | kismayo
# Processing Record 32 of Set 14 | kjollefjord
# Processing Record 33 of Set 14 | san felipe
# Processing Record 34 of Set 14 | bam
# Processing Record 35 of Set 14 | dhamrai
# Processing Record 36 of Set 14 | harper
# Processing Record 37 of Set 14 | cayenne
# Processing Record 38 of Set 14 | mattawa
# Processing Record 39 of Set 14 | isangel
# Processing Record 40 of Set 14 | castleblayney
# Processing Record 41 of Set 14 | yangcun
# Processing Record 42 of Set 14 | entre rios
# Processing Record 43 of Set 14 | manono
# Processing Record 44 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 14 | sheridan
# Processing Record 46 of Set 14 | mehndawal
# Processing Record 47 of Set 14 | chara
# Processing Record 48 of Set 14 | sindal
# Processing Record 49 of Set 14 | evinayong
# Processing Record 50 of Set 14 | bilibino
# Processing Record 1 of Set 15 | mineiros
# Processing Record 2 of Set 15 | caceres
# Processing Record 3 of Set 15 | veraval
# Processing Record 4 of Set 15 | bonfim
# Processing Record 5 of Set 15 | tooele
# Processing Record 6 of Set 15 | nhulunbuy
# Processing Record 7 of Set 15 | rawlins
# Processing Record 8 of Set 15 | danville
# Processing Record 9 of Set 15 | chamba
# Processing Record 10 of Set 15 | kloulklubed
# Processing Record 11 of Set 15 | charleston
# Processing Record 12 of Set 15 | southbridge
# Processing Record 13 of Set 15 | vilyuysk
# Processing Record 14 of Set 15 | petropavlovka
# Processing Record 15 of Set 15 | victoria point
# Processing Record 16 of Set 15 | abu samrah
# Processing Record 17 of Set 15 | ibotirama
# Processing Record 18 of Set 15 | oxford
# Processing Record 19 of Set 15 | champerico
# Processing Record 20 of Set 15 | muros
# Processing Record 21 of Set 15 | makakilo city
# Processing Record 22 of Set 15 | sorland
# Processing Record 23 of Set 15 | anaconda
# Processing Record 24 of Set 15 | versmold
# Processing Record 25 of Set 15 | sikasso
# Processing Record 26 of Set 15 | kamenka
# Processing Record 27 of Set 15 | karacakoy
# Processing Record 28 of Set 15 | shishou
# Processing Record 29 of Set 15 | gorin
# Processing Record 30 of Set 15 | poso
# Processing Record 31 of Set 15 | angoche
# Processing Record 32 of Set 15 | araouane
# Processing Record 33 of Set 15 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 15 | mandan
# Processing Record 35 of Set 15 | toppenish
# Processing Record 36 of Set 15 | sturgeon falls
# Processing Record 37 of Set 15 | praia da vitoria
# Processing Record 38 of Set 15 | gat
# Processing Record 39 of Set 15 | sapao
# City not found. Skipping...
# Processing Record 40 of Set 15 | semnan
# Processing Record 41 of Set 15 | bac lieu
# Processing Record 42 of Set 15 | darhan
# Processing Record 43 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 44 of Set 15 | adamas
# Processing Record 45 of Set 15 | lyubim
# Processing Record 46 of Set 15 | wencheng
# Processing Record 47 of Set 15 | agirish
# Processing Record 48 of Set 15 | orange
# Processing Record 49 of Set 15 | santo domingo
# Processing Record 50 of Set 15 | puerto carreno
# Processing Record 1 of Set 16 | sur
# Processing Record 2 of Set 16 | callaway
# Processing Record 3 of Set 16 | mandera
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check data to make sure all data is pulled correctly
city_data
# Out:
# [{'City': 'Luwuk',
#   'Country': 'ID',
#   'Lat': -0.9516,
#   'Lng': 122.7875,
#   'Max Temp': 76.8,
#   'Humidity': 85,
#   'Cloudiness': 20,
#   'Wind Speed': 2.35,
#   'Date': '2021-04-12 17:23:44',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:23:44',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Saldanha',
#   'Country': 'ZA',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 73.4,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:20:02',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Airai',
#   'Country': 'TL',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 56.91,
#   'Humidity': 83,
#   'Cloudiness': 83,
#   'Wind Speed': 2.21,
#   'Date': '2021-04-12 17:23:45',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Itupiranga',
#   'Country': 'BR',
#   'Lat': -5.1347,
#   'Lng': -49.3267,
#   'Max Temp': 93.2,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:23:37',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 48.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:20:23',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 50,
#   'Humidity': 40,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 17:23:46',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Maragogi',
#   'Country': 'BR',
#   'Lat': -9.0122,
#   'Lng': -35.2225,
#   'Max Temp': 82.83,
#   'Humidity': 70,
#   'Cloudiness': 96,
#   'Wind Speed': 7.92,
#   'Date': '2021-04-12 17:23:46',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 48.99,
#   'Humidity': 94,
#   'Cloudiness': 98,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 17:23:47',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 95,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 17:23:47',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 5.14,
#   'Date': '2021-04-12 17:23:47',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 21.2,
#   'Humidity': 53,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Date': '2021-04-12 17:23:48',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Constitucion',
#   'Country': 'CL',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 69.8,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 14.9,
#   'Date': '2021-04-12 17:23:48',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Santa Isabel',
#   'Country': 'BR',
#   'Lat': -23.3156,
#   'Lng': -46.2214,
#   'Max Temp': 84.2,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:20:48',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Roma',
#   'Country': 'US',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 50,
#   'Humidity': 62,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:21:21',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Balabac',
#   'Country': 'PH',
#   'Lat': 7.9868,
#   'Lng': 117.0645,
#   'Max Temp': 80.69,
#   'Humidity': 79,
#   'Cloudiness': 49,
#   'Wind Speed': 3.49,
#   'Date': '2021-04-12 17:23:49',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 66.99,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:21:40',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 12.45,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 17.22,
#   'Date': '2021-04-12 17:23:49',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 53.01,
#   'Humidity': 68,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Date': '2021-04-12 17:23:50',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Shiyan',
#   'Country': 'CN',
#   'Lat': 32.6475,
#   'Lng': 110.7781,
#   'Max Temp': 63.28,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 0.18,
#   'Date': '2021-04-12 17:23:50',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Valle De Allende',
#   'Country': 'MX',
#   'Lat': 26.9333,
#   'Lng': -105.4,
#   'Max Temp': 76.35,
#   'Humidity': 11,
#   'Cloudiness': 8,
#   'Wind Speed': 3.47,
#   'Date': '2021-04-12 17:23:50',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Andreapol',
#   'Country': 'RU',
#   'Lat': 56.6513,
#   'Lng': 32.2664,
#   'Max Temp': 50.41,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 9.46,
#   'Date': '2021-04-12 17:23:51',
#   'Current Descripion': 'light rain'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 63.1,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 15.35,
#   'Date': '2021-04-12 17:23:51',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 50,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 28.77,
#   'Date': '2021-04-12 17:20:07',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Santa Vitoria Do Palmar',
#   'Country': 'BR',
#   'Lat': -33.5189,
#   'Lng': -53.3681,
#   'Max Temp': 70.34,
#   'Humidity': 52,
#   'Cloudiness': 0,
#   'Wind Speed': 5.7,
#   'Date': '2021-04-12 17:23:52',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Caohai',
#   'Country': 'CN',
#   'Lat': 26.8661,
#   'Lng': 104.2841,
#   'Max Temp': 50.59,
#   'Humidity': 87,
#   'Cloudiness': 34,
#   'Wind Speed': 6.29,
#   'Date': '2021-04-12 17:23:52',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Guerrero Negro',
#   'Country': 'MX',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 63.91,
#   'Humidity': 61,
#   'Cloudiness': 3,
#   'Wind Speed': 13.53,
#   'Date': '2021-04-12 17:23:52',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Margate',
#   'Country': 'GB',
#   'Lat': 51.3813,
#   'Lng': 1.3862,
#   'Max Temp': 48,
#   'Humidity': 60,
#   'Cloudiness': 34,
#   'Wind Speed': 1.01,
#   'Date': '2021-04-12 17:23:53',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.95,
#   'Humidity': 69,
#   'Cloudiness': 72,
#   'Wind Speed': 10.51,
#   'Date': '2021-04-12 17:21:14',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Alice Springs',
#   'Country': 'AU',
#   'Lat': -23.7,
#   'Lng': 133.8833,
#   'Max Temp': 57,
#   'Humidity': 62,
#   'Cloudiness': 92,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:20:52',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Pontianak',
#   'Country': 'ID',
#   'Lat': -0.0333,
#   'Lng': 109.3333,
#   'Max Temp': 75.92,
#   'Humidity': 88,
#   'Cloudiness': 81,
#   'Wind Speed': 0.81,
#   'Date': '2021-04-12 17:23:54',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Georgetown',
#   'Country': 'MY',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 82,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 17:23:54',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': -0.09,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 12.68,
#   'Date': '2021-04-12 17:23:55',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'College',
#   'Country': 'US',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': 32,
#   'Humidity': 59,
#   'Cloudiness': 90,
#   'Wind Speed': 1.28,
#   'Date': '2021-04-12 17:23:55',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Traverse City',
#   'Country': 'US',
#   'Lat': 44.7631,
#   'Lng': -85.6206,
#   'Max Temp': 53.6,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 2.1,
#   'Date': '2021-04-12 17:23:55',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Popondetta',
#   'Country': 'PG',
#   'Lat': -8.7537,
#   'Lng': 148.2534,
#   'Max Temp': 72.59,
#   'Humidity': 93,
#   'Cloudiness': 99,
#   'Wind Speed': 2.62,
#   'Date': '2021-04-12 17:23:56',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 18.45,
#   'Humidity': 90,
#   'Cloudiness': 79,
#   'Wind Speed': 11.61,
#   'Date': '2021-04-12 17:23:56',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Bambous Virieux',
#   'Country': 'MU',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:23:56',
#   'Current Descripion': 'light rain'},
#  {'City': 'Sitka',
#   'Country': 'US',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:23:57',
#   'Current Descripion': 'light snow'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:23:57',
#   'Current Descripion': 'light rain'},
#  {'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -14.8,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 17:23:58',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Geraldton',
#   'Country': 'AU',
#   'Lat': -28.7667,
#   'Lng': 114.6,
#   'Max Temp': 66.2,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:23:58',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 17:23:59',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 77.34,
#   'Humidity': 62,
#   'Cloudiness': 23,
#   'Wind Speed': 5.53,
#   'Date': '2021-04-12 17:23:59',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 93.2,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:23:59',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Bolu',
#   'Country': 'TR',
#   'Lat': 40.6667,
#   'Lng': 31.5833,
#   'Max Temp': 35.56,
#   'Humidity': 95,
#   'Cloudiness': 94,
#   'Wind Speed': 1.57,
#   'Date': '2021-04-12 17:24:00',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -27.13,
#   'Humidity': 100,
#   'Cloudiness': 41,
#   'Wind Speed': 2.13,
#   'Date': '2021-04-12 17:24:00',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 73.26,
#   'Humidity': 89,
#   'Cloudiness': 16,
#   'Wind Speed': 2.66,
#   'Date': '2021-04-12 17:24:00',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 54,
#   'Humidity': 89,
#   'Cloudiness': 96,
#   'Wind Speed': 11.18,
#   'Date': '2021-04-12 17:24:01',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Saint-Francois',
#   'Country': 'FR',
#   'Lat': 46.4154,
#   'Lng': 3.9054,
#   'Max Temp': 48.2,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:24:01',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Kaitangata',
#   'Country': 'NZ',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 50.61,
#   'Humidity': 97,
#   'Cloudiness': 66,
#   'Wind Speed': 4.59,
#   'Date': '2021-04-12 17:24:01',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 46.99,
#   'Humidity': 88,
#   'Cloudiness': 35,
#   'Wind Speed': 2.28,
#   'Date': '2021-04-12 17:24:02',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 7.99,
#   'Humidity': 80,
#   'Cloudiness': 78,
#   'Wind Speed': 4.12,
#   'Date': '2021-04-12 17:24:02',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Mgachi',
#   'Country': 'RU',
#   'Lat': 51.05,
#   'Lng': 142.2667,
#   'Max Temp': 31.39,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 5.19,
#   'Date': '2021-04-12 17:24:02',
#   'Current Descripion': 'light snow'},
#  {'City': 'Iquitos',
#   'Country': 'PE',
#   'Lat': -3.7481,
#   'Lng': -73.2472,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:22:52',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.04,
#   'Humidity': 77,
#   'Cloudiness': 96,
#   'Wind Speed': 14,
#   'Date': '2021-04-12 17:24:03',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 30.2,
#   'Humidity': 64,
#   'Cloudiness': 11,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:04',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Laguna De Duero',
#   'Country': 'ES',
#   'Lat': 41.5815,
#   'Lng': -4.7233,
#   'Max Temp': 59,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:04',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Country': 'RU',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': 5.76,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 15.01,
#   'Date': '2021-04-12 17:24:04',
#   'Current Descripion': 'light snow'},
#  {'City': 'Monte Aprazivel',
#   'Country': 'BR',
#   'Lat': -20.7725,
#   'Lng': -49.7142,
#   'Max Temp': 87.8,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 17:24:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Aksu',
#   'Country': 'CN',
#   'Lat': 41.1231,
#   'Lng': 80.2644,
#   'Max Temp': 59.25,
#   'Humidity': 34,
#   'Cloudiness': 7,
#   'Wind Speed': 12.48,
#   'Date': '2021-04-12 17:24:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Myaundzha',
#   'Country': 'RU',
#   'Lat': 63.0494,
#   'Lng': 147.1858,
#   'Max Temp': -23.98,
#   'Humidity': 98,
#   'Cloudiness': 10,
#   'Wind Speed': 2.8,
#   'Date': '2021-04-12 17:24:06',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Isiro',
#   'Country': 'CD',
#   'Lat': 2.7739,
#   'Lng': 27.616,
#   'Max Temp': 67.87,
#   'Humidity': 99,
#   'Cloudiness': 98,
#   'Wind Speed': 3.51,
#   'Date': '2021-04-12 17:24:06',
#   'Current Descripion': 'very heavy rain'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Date': '2021-04-12 17:24:07',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Saint-Augustin',
#   'Country': 'CA',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 46.72,
#   'Humidity': 71,
#   'Cloudiness': 7,
#   'Wind Speed': 22.68,
#   'Date': '2021-04-12 17:24:07',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 64.4,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:08',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 25.48,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 19.24,
#   'Date': '2021-04-12 17:24:08',
#   'Current Descripion': 'light snow'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 78.15,
#   'Humidity': 70,
#   'Cloudiness': 14,
#   'Wind Speed': 10.13,
#   'Date': '2021-04-12 17:24:08',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Wawa',
#   'Country': 'NG',
#   'Lat': 9.9022,
#   'Lng': 4.4192,
#   'Max Temp': 99.77,
#   'Humidity': 25,
#   'Cloudiness': 39,
#   'Wind Speed': 5.39,
#   'Date': '2021-04-12 17:24:09',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Grand Gaube',
#   'Country': 'MU',
#   'Lat': -20.0064,
#   'Lng': 57.6608,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:24:10',
#   'Current Descripion': 'light rain'},
#  {'City': 'Yurimaguas',
#   'Country': 'PE',
#   'Lat': -5.9,
#   'Lng': -76.0833,
#   'Max Temp': 89.6,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:24:10',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Ahuimanu',
#   'Country': 'US',
#   'Lat': 21.4447,
#   'Lng': -157.8378,
#   'Max Temp': 71.6,
#   'Humidity': 73,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:10',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Bera',
#   'Country': 'BD',
#   'Lat': 24.0833,
#   'Lng': 89.6167,
#   'Max Temp': 85.33,
#   'Humidity': 41,
#   'Cloudiness': 42,
#   'Wind Speed': 7.72,
#   'Date': '2021-04-12 17:24:11',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 73.54,
#   'Humidity': 72,
#   'Cloudiness': 71,
#   'Wind Speed': 7.94,
#   'Date': '2021-04-12 17:24:12',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 101.28,
#   'Humidity': 6,
#   'Cloudiness': 1,
#   'Wind Speed': 11.52,
#   'Date': '2021-04-12 17:24:12',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Griffith',
#   'Country': 'US',
#   'Lat': 41.5284,
#   'Lng': -87.4237,
#   'Max Temp': 63,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 17:24:12',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:24:13',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Kattivakkam',
#   'Country': 'IN',
#   'Lat': 13.2167,
#   'Lng': 80.3167,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:13',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Kahului',
#   'Country': 'US',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 6.6,
#   'Date': '2021-04-12 17:24:02',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Lompoc',
#   'Country': 'US',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 50,
#   'Humidity': 87,
#   'Cloudiness': 43,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:14',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Loncoche',
#   'Country': 'CL',
#   'Lat': -39.3667,
#   'Lng': -72.6333,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:24:14',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 77.72,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 0.83,
#   'Date': '2021-04-12 17:24:14',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:24:15',
#   'Current Descripion': 'light rain'},
#  {'City': 'Sidi Ali',
#   'Country': 'DZ',
#   'Lat': 36.0998,
#   'Lng': 0.4206,
#   'Max Temp': 60.82,
#   'Humidity': 75,
#   'Cloudiness': 74,
#   'Wind Speed': 15.66,
#   'Date': '2021-04-12 17:24:15',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 24.26,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind Speed': 10.63,
#   'Date': '2021-04-12 17:24:16',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Meulaboh',
#   'Country': 'ID',
#   'Lat': 4.1363,
#   'Lng': 96.1285,
#   'Max Temp': 77.54,
#   'Humidity': 86,
#   'Cloudiness': 88,
#   'Wind Speed': 4.29,
#   'Date': '2021-04-12 17:24:16',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Bethel',
#   'Country': 'US',
#   'Lat': 41.3712,
#   'Lng': -73.414,
#   'Max Temp': 51.8,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:17',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Aiken',
#   'Country': 'US',
#   'Lat': 33.5835,
#   'Lng': -81.5998,
#   'Max Temp': 82,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 17:24:17',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 75.99,
#   'Humidity': 84,
#   'Cloudiness': 45,
#   'Wind Speed': 4.5,
#   'Date': '2021-04-12 17:22:02',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 75.2,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:24:17',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Christchurch',
#   'Country': 'NZ',
#   'Lat': -43.5333,
#   'Lng': 172.6333,
#   'Max Temp': 59,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:21:37',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Ossora',
#   'Country': 'RU',
#   'Lat': 59.2353,
#   'Lng': 163.0719,
#   'Max Temp': 2.73,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 5.59,
#   'Date': '2021-04-12 17:24:18',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Petrozavodsk',
#   'Country': 'RU',
#   'Lat': 61.7849,
#   'Lng': 34.3469,
#   'Max Temp': 55.4,
#   'Humidity': 41,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Date': '2021-04-12 17:21:46',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Manokwari',
#   'Country': 'ID',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 79.11,
#   'Humidity': 79,
#   'Cloudiness': 99,
#   'Wind Speed': 4.25,
#   'Date': '2021-04-12 17:24:19',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:19',
#   'Current Descripion': 'light rain'},
#  {'City': 'Avera',
#   'Country': 'US',
#   'Lat': 33.194,
#   'Lng': -82.5271,
#   'Max Temp': 82.99,
#   'Humidity': 26,
#   'Cloudiness': 1,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 17:24:20',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 80.55,
#   'Humidity': 69,
#   'Cloudiness': 65,
#   'Wind Speed': 8.99,
#   'Date': '2021-04-12 17:24:20',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Vavuniya',
#   'Country': 'LK',
#   'Lat': 8.7514,
#   'Lng': 80.4971,
#   'Max Temp': 74.48,
#   'Humidity': 93,
#   'Cloudiness': 32,
#   'Wind Speed': 3.24,
#   'Date': '2021-04-12 17:24:21',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Kalmunai',
#   'Country': 'LK',
#   'Lat': 7.4167,
#   'Lng': 81.8167,
#   'Max Temp': 80.6,
#   'Humidity': 76,
#   'Cloudiness': 46,
#   'Wind Speed': 5.03,
#   'Date': '2021-04-12 17:24:21',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 57,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:21',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -24.45,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 6.13,
#   'Date': '2021-04-12 17:24:22',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'San Cristobal',
#   'Country': 'VE',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 93.2,
#   'Humidity': 40,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Date': '2021-04-12 17:24:22',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 30.87,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 13.15,
#   'Date': '2021-04-12 17:24:23',
#   'Current Descripion': 'light snow'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 71.38,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 14.47,
#   'Date': '2021-04-12 17:24:23',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'San Policarpo',
#   'Country': 'PH',
#   'Lat': 12.1791,
#   'Lng': 125.5072,
#   'Max Temp': 79.03,
#   'Humidity': 85,
#   'Cloudiness': 56,
#   'Wind Speed': 9.28,
#   'Date': '2021-04-12 17:24:24',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Leningradskiy',
#   'Country': 'RU',
#   'Lat': 69.3833,
#   'Lng': 178.4167,
#   'Max Temp': -7.65,
#   'Humidity': 82,
#   'Cloudiness': 99,
#   'Wind Speed': 7.05,
#   'Date': '2021-04-12 17:24:24',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Ravar',
#   'Country': 'IR',
#   'Lat': 31.2656,
#   'Lng': 56.8055,
#   'Max Temp': 74.08,
#   'Humidity': 26,
#   'Cloudiness': 88,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:24:25',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Luderitz',
#   'Country': 'NA',
#   'Lat': -26.6481,
#   'Lng': 15.1594,
#   'Max Temp': 77.76,
#   'Humidity': 43,
#   'Cloudiness': 6,
#   'Wind Speed': 6.64,
#   'Date': '2021-04-12 17:24:25',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 66.99,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Date': '2021-04-12 17:24:25',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Santa Isabel Do Rio Negro',
#   'Country': 'BR',
#   'Lat': -0.4139,
#   'Lng': -65.0192,
#   'Max Temp': 83.71,
#   'Humidity': 77,
#   'Cloudiness': 50,
#   'Wind Speed': 2.89,
#   'Date': '2021-04-12 17:24:26',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Qinzhou',
#   'Country': 'CN',
#   'Lat': 21.95,
#   'Lng': 108.6167,
#   'Max Temp': 75.29,
#   'Humidity': 81,
#   'Cloudiness': 78,
#   'Wind Speed': 6.26,
#   'Date': '2021-04-12 17:24:26',
#   'Current Descripion': 'light rain'},
#  {'City': 'Bengkulu',
#   'Country': 'ID',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.26,
#   'Humidity': 88,
#   'Cloudiness': 91,
#   'Wind Speed': 4.09,
#   'Date': '2021-04-12 17:24:26',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Tuatapere',
#   'Country': 'NZ',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 48.99,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 17:24:27',
#   'Current Descripion': 'moderate rain'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 7,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:24:27',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Champua',
#   'Country': 'IN',
#   'Lat': 22.0833,
#   'Lng': 85.6667,
#   'Max Temp': 77.61,
#   'Humidity': 55,
#   'Cloudiness': 24,
#   'Wind Speed': 10.25,
#   'Date': '2021-04-12 17:24:28',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Dudinka',
#   'Country': 'RU',
#   'Lat': 69.4058,
#   'Lng': 86.1778,
#   'Max Temp': 22.03,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 12.15,
#   'Date': '2021-04-12 17:24:28',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 66.99,
#   'Humidity': 15,
#   'Cloudiness': 1,
#   'Wind Speed': 3.58,
#   'Date': '2021-04-12 17:21:37',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Polson',
#   'Country': 'US',
#   'Lat': 47.6936,
#   'Lng': -114.1632,
#   'Max Temp': 37.99,
#   'Humidity': 79,
#   'Cloudiness': 9,
#   'Wind Speed': 3,
#   'Date': '2021-04-12 17:24:29',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Ust-Maya',
#   'Country': 'RU',
#   'Lat': 60.4167,
#   'Lng': 134.5333,
#   'Max Temp': -7.92,
#   'Humidity': 99,
#   'Cloudiness': 45,
#   'Wind Speed': 1.61,
#   'Date': '2021-04-12 17:24:29',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Gazli',
#   'Country': 'UZ',
#   'Lat': 40.1333,
#   'Lng': 63.45,
#   'Max Temp': 65.73,
#   'Humidity': 17,
#   'Cloudiness': 76,
#   'Wind Speed': 10,
#   'Date': '2021-04-12 17:24:30',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 75.29,
#   'Humidity': 73,
#   'Cloudiness': 87,
#   'Wind Speed': 23.06,
#   'Date': '2021-04-12 17:20:17',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Port Hawkesbury',
#   'Country': 'CA',
#   'Lat': 45.6169,
#   'Lng': -61.3485,
#   'Max Temp': 51.01,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:24:30',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -27.6,
#   'Humidity': 100,
#   'Cloudiness': 19,
#   'Wind Speed': 3.18,
#   'Date': '2021-04-12 17:24:31',
#   'Current Descripion': 'few clouds'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 30.2,
#   'Humidity': 43,
#   'Cloudiness': 93,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:24:31',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Vicksburg',
#   'Country': 'US',
#   'Lat': 32.3526,
#   'Lng': -90.8779,
#   'Max Temp': 78.8,
#   'Humidity': 38,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 17:24:31',
#   'Current Descripion': 'clear sky'},
#  {'City': 'San Ignacio',
#   'Country': 'BZ',
#   'Lat': 17.1561,
#   'Lng': -89.0714,
#   'Max Temp': 91.4,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:24:32',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 77.52,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 13.02,
#   'Date': '2021-04-12 17:24:32',
#   'Current Descripion': 'moderate rain'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 39.2,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:24:32',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 78.01,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:33',
#   'Current Descripion': 'light rain'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 48.99,
#   'Humidity': 94,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 17:24:33',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Sidney',
#   'Country': 'AU',
#   'Lat': -33.8679,
#   'Lng': 151.2073,
#   'Max Temp': 52,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 17:22:36',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Talara',
#   'Country': 'PE',
#   'Lat': -4.5772,
#   'Lng': -81.2719,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 17:23:20',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Bitkine',
#   'Country': 'TD',
#   'Lat': 11.9801,
#   'Lng': 18.2138,
#   'Max Temp': 94.75,
#   'Humidity': 8,
#   'Cloudiness': 88,
#   'Wind Speed': 7.18,
#   'Date': '2021-04-12 17:24:34',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Wanning',
#   'Country': 'CN',
#   'Lat': 18.8003,
#   'Lng': 110.3967,
#   'Max Temp': 74.71,
#   'Humidity': 91,
#   'Cloudiness': 6,
#   'Wind Speed': 3.38,
#   'Date': '2021-04-12 17:24:35',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.17,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 13.53,
#   'Date': '2021-04-12 17:24:35',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Berlevag',
#   'Country': 'NO',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 32,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02,
#   'Date': '2021-04-12 17:24:36',
#   'Current Descripion': 'light snow'},
#  {'City': 'Pilar',
#   'Country': 'BR',
#   'Lat': -9.5972,
#   'Lng': -35.9567,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 17:24:36',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Gravdal',
#   'Country': 'NO',
#   'Lat': 68.1214,
#   'Lng': 13.5031,
#   'Max Temp': 35.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:24:36',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 82.85,
#   'Humidity': 74,
#   'Cloudiness': 73,
#   'Wind Speed': 2.8,
#   'Date': '2021-04-12 17:24:37',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:24:37',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Upata',
#   'Country': 'VE',
#   'Lat': 8.0086,
#   'Lng': -62.3989,
#   'Max Temp': 90,
#   'Humidity': 62,
#   'Cloudiness': 88,
#   'Wind Speed': 5.01,
#   'Date': '2021-04-12 17:24:38',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 37.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:24:38',
#   'Current Descripion': 'light rain'},
#  {'City': 'State College',
#   'Country': 'US',
#   'Lat': 40.7934,
#   'Lng': -77.86,
#   'Max Temp': 54,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:21:21',
#   'Current Descripion': 'light rain'},
#  {'City': 'Colares',
#   'Country': 'PT',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 64,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:24:39',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Dunedin',
#   'Country': 'NZ',
#   'Lat': -45.8742,
#   'Lng': 170.5036,
#   'Max Temp': 55.99,
#   'Humidity': 71,
#   'Cloudiness': 41,
#   'Wind Speed': 6.78,
#   'Date': '2021-04-12 17:24:39',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Coahuayana',
#   'Country': 'MX',
#   'Lat': 18.7333,
#   'Lng': -103.6833,
#   'Max Temp': 80.6,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:24:39',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 81.73,
#   'Humidity': 65,
#   'Cloudiness': 2,
#   'Wind Speed': 6.46,
#   'Date': '2021-04-12 17:24:40',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Barreirinha',
#   'Country': 'BR',
#   'Lat': -2.7933,
#   'Lng': -57.07,
#   'Max Temp': 90.59,
#   'Humidity': 52,
#   'Cloudiness': 89,
#   'Wind Speed': 3.04,
#   'Date': '2021-04-12 17:24:40',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Kroya',
#   'Country': 'ID',
#   'Lat': -7.6331,
#   'Lng': 109.2461,
#   'Max Temp': 79.21,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind Speed': 1.7,
#   'Date': '2021-04-12 17:24:41',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Sorong',
#   'Country': 'ID',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 79.74,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 6.15,
#   'Date': '2021-04-12 17:24:41',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Athabasca',
#   'Country': 'CA',
#   'Lat': 54.7169,
#   'Lng': -113.2854,
#   'Max Temp': 33.8,
#   'Humidity': 55,
#   'Cloudiness': 64,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:41',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Kazachinskoye',
#   'Country': 'RU',
#   'Lat': 57.6953,
#   'Lng': 93.2761,
#   'Max Temp': 34.36,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 8.37,
#   'Date': '2021-04-12 17:24:42',
#   'Current Descripion': 'light snow'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.21,
#   'Humidity': 80,
#   'Cloudiness': 48,
#   'Wind Speed': 16.75,
#   'Date': '2021-04-12 17:24:42',
#   'Current Descripion': 'light rain'},
#  {'City': 'Lhokseumawe',
#   'Country': 'ID',
#   'Lat': 5.1801,
#   'Lng': 97.1507,
#   'Max Temp': 77.59,
#   'Humidity': 86,
#   'Cloudiness': 23,
#   'Wind Speed': 4.7,
#   'Date': '2021-04-12 17:24:42',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Jati',
#   'Country': 'PK',
#   'Lat': 24.3539,
#   'Lng': 68.2671,
#   'Max Temp': 81.84,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 12.46,
#   'Date': '2021-04-12 17:24:43',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Santa Maria',
#   'Country': 'BR',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 71.6,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:43',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Baykalovo',
#   'Country': 'RU',
#   'Lat': 57.3981,
#   'Lng': 63.7684,
#   'Max Temp': 40.59,
#   'Humidity': 82,
#   'Cloudiness': 12,
#   'Wind Speed': 7.09,
#   'Date': '2021-04-12 17:24:44',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Saint-Joseph',
#   'Country': 'RE',
#   'Lat': -21.3667,
#   'Lng': 55.6167,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:24:44',
#   'Current Descripion': 'light rain'},
#  {'City': 'Bowen',
#   'Country': 'AU',
#   'Lat': -20.0167,
#   'Lng': 148.2333,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:24:45',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Fomboni',
#   'Country': 'KM',
#   'Lat': -12.28,
#   'Lng': 43.7425,
#   'Max Temp': 83.97,
#   'Humidity': 72,
#   'Cloudiness': 96,
#   'Wind Speed': 18.72,
#   'Date': '2021-04-12 17:24:46',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Mbandaka',
#   'Country': 'CD',
#   'Lat': 0.0487,
#   'Lng': 18.2603,
#   'Max Temp': 78.31,
#   'Humidity': 72,
#   'Cloudiness': 95,
#   'Wind Speed': 1.59,
#   'Date': '2021-04-12 17:24:46',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Sobolevo',
#   'Country': 'RU',
#   'Lat': 54.4299,
#   'Lng': 31.8996,
#   'Max Temp': 48.06,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 5.08,
#   'Date': '2021-04-12 17:24:46',
#   'Current Descripion': 'light rain'},
#  {'City': 'San Agustin',
#   'Country': 'MX',
#   'Lat': 20.5333,
#   'Lng': -103.4667,
#   'Max Temp': 81,
#   'Humidity': 18,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 17:24:47',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Gushikawa',
#   'Country': 'JP',
#   'Lat': 26.3544,
#   'Lng': 127.8686,
#   'Max Temp': 73.4,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 17:24:47',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 30.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 17:24:48',
#   'Current Descripion': 'light snow'},
#  {'City': 'Leshukonskoye',
#   'Country': 'RU',
#   'Lat': 64.8989,
#   'Lng': 45.7622,
#   'Max Temp': 40.62,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 9.8,
#   'Date': '2021-04-12 17:24:48',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Ondjiva',
#   'Country': 'AO',
#   'Lat': -17.0667,
#   'Lng': 15.7333,
#   'Max Temp': 84.2,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:49',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Cidreira',
#   'Country': 'BR',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 71.89,
#   'Humidity': 64,
#   'Cloudiness': 93,
#   'Wind Speed': 12.73,
#   'Date': '2021-04-12 17:24:49',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Tawang',
#   'Country': 'IN',
#   'Lat': 27.5833,
#   'Lng': 91.8667,
#   'Max Temp': 42.67,
#   'Humidity': 73,
#   'Cloudiness': 58,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:24:50',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Jinxi',
#   'Country': 'CN',
#   'Lat': 30.4323,
#   'Lng': 116.2922,
#   'Max Temp': 61.16,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 2.64,
#   'Date': '2021-04-12 17:24:51',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Bystryy Istok',
#   'Country': 'RU',
#   'Lat': 52.371,
#   'Lng': 84.3873,
#   'Max Temp': 34.05,
#   'Humidity': 97,
#   'Cloudiness': 97,
#   'Wind Speed': 3.87,
#   'Date': '2021-04-12 17:24:51',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:24:51',
#   'Current Descripion': 'light rain'},
#  {'City': 'Barcelos',
#   'Country': 'PT',
#   'Lat': 41.5388,
#   'Lng': -8.6151,
#   'Max Temp': 66.2,
#   'Humidity': 42,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:24:52',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Marawi',
#   'Country': 'PH',
#   'Lat': 7.9986,
#   'Lng': 124.2928,
#   'Max Temp': 75.99,
#   'Humidity': 88,
#   'Cloudiness': 58,
#   'Wind Speed': 4,
#   'Date': '2021-04-12 17:24:52',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Shache',
#   'Country': 'CN',
#   'Lat': 38.4167,
#   'Lng': 77.2406,
#   'Max Temp': 63,
#   'Humidity': 20,
#   'Cloudiness': 25,
#   'Wind Speed': 7.36,
#   'Date': '2021-04-12 17:20:19',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 17:24:53',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Hay River',
#   'Country': 'CA',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 19.4,
#   'Humidity': 45,
#   'Cloudiness': 32,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 17:24:53',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Caravelas',
#   'Country': 'BR',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 86.18,
#   'Humidity': 47,
#   'Cloudiness': 28,
#   'Wind Speed': 9.82,
#   'Date': '2021-04-12 17:24:54',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Vranovice',
#   'Country': 'CZ',
#   'Lat': 48.966,
#   'Lng': 16.6066,
#   'Max Temp': 44.01,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Date': '2021-04-12 17:24:54',
#   'Current Descripion': 'light rain'},
#  {'City': 'Oranjestad',
#   'Country': 'AW',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 25.32,
#   'Date': '2021-04-12 17:24:55',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Sisimiut',
#   'Country': 'GL',
#   'Lat': 66.9395,
#   'Lng': -53.6735,
#   'Max Temp': 36.18,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 8.95,
#   'Date': '2021-04-12 17:24:55',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Naruja',
#   'Country': 'GE',
#   'Lat': 41.9069,
#   'Lng': 41.9542,
#   'Max Temp': 50,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 17:24:55',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Plouzane',
#   'Country': 'FR',
#   'Lat': 48.3833,
#   'Lng': -4.6167,
#   'Max Temp': 51.8,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:24:56',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Ayan',
#   'Country': 'RU',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': 10.09,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 6.08,
#   'Date': '2021-04-12 17:24:56',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Songea',
#   'Country': 'TZ',
#   'Lat': -10.6833,
#   'Lng': 35.65,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:24:57',
#   'Current Descripion': 'light rain'},
#  {'City': 'Leh',
#   'Country': 'IN',
#   'Lat': 34.1667,
#   'Lng': 77.5833,
#   'Max Temp': 32.52,
#   'Humidity': 54,
#   'Cloudiness': 33,
#   'Wind Speed': 3.49,
#   'Date': '2021-04-12 17:24:57',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Walvis Bay',
#   'Country': 'NA',
#   'Lat': -22.9575,
#   'Lng': 14.5053,
#   'Max Temp': 91.4,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:24:57',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Leo',
#   'Country': 'BF',
#   'Lat': 11.1,
#   'Lng': -2.1,
#   'Max Temp': 105.21,
#   'Humidity': 10,
#   'Cloudiness': 5,
#   'Wind Speed': 8.95,
#   'Date': '2021-04-12 17:24:58',
#   'Current Descripion': 'clear sky'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 17:24:58',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Chincha Alta',
#   'Country': 'PE',
#   'Lat': -13.4099,
#   'Lng': -76.1323,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:24:59',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 70.23,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 6.2,
#   'Date': '2021-04-12 17:24:59',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Kautokeino',
#   'Country': 'NO',
#   'Lat': 69.0125,
#   'Lng': 23.0412,
#   'Max Temp': 17.19,
#   'Humidity': 85,
#   'Cloudiness': 3,
#   'Wind Speed': 1.95,
#   'Date': '2021-04-12 17:24:59',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Isperih',
#   'Country': 'BG',
#   'Lat': 43.7167,
#   'Lng': 26.8333,
#   'Max Temp': 51.6,
#   'Humidity': 54,
#   'Cloudiness': 11,
#   'Wind Speed': 2.86,
#   'Date': '2021-04-12 17:25:00',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Castro',
#   'Country': 'BR',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 76.23,
#   'Humidity': 68,
#   'Cloudiness': 24,
#   'Wind Speed': 6.4,
#   'Date': '2021-04-12 17:25:00',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Kuryk',
#   'Country': 'KZ',
#   'Lat': 43.2,
#   'Lng': 51.65,
#   'Max Temp': 63.21,
#   'Humidity': 37,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Date': '2021-04-12 17:25:00',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 35.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 17:25:01',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 57.2,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Date': '2021-04-12 17:25:01',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Anloga',
#   'Country': 'GH',
#   'Lat': 5.7947,
#   'Lng': 0.8973,
#   'Max Temp': 87.8,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:25:01',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 17:25:03',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Mount Isa',
#   'Country': 'AU',
#   'Lat': -20.7333,
#   'Lng': 139.5,
#   'Max Temp': 59,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 17:25:03',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -5.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:25:04',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Arroyo',
#   'Country': 'ES',
#   'Lat': 41.6096,
#   'Lng': -4.7969,
#   'Max Temp': 59,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:25:04',
#   'Current Descripion': 'light rain'},
#  {'City': 'Praia',
#   'Country': 'CV',
#   'Lat': 14.9215,
#   'Lng': -23.5087,
#   'Max Temp': 86,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Date': '2021-04-12 17:25:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 59,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Date': '2021-04-12 17:25:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Port Hedland',
#   'Country': 'AU',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 42,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:25:06',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Racova',
#   'Country': 'RO',
#   'Lat': 46.7,
#   'Lng': 26.75,
#   'Max Temp': 60.8,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 17:25:06',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Nusaybin',
#   'Country': 'TR',
#   'Lat': 37.0778,
# ...
#   'Current Descripion': 'clear sky'},
#  {'City': 'Kismayo',
#   'Country': 'SO',
#   'Lat': -0.3582,
#   'Lng': 42.5454,
#   'Max Temp': 83.19,
#   'Humidity': 71,
#   'Cloudiness': 11,
#   'Wind Speed': 9.44,
#   'Date': '2021-04-12 17:27:51',
#   'Current Descripion': 'few clouds'},
#  {'City': 'Kjollefjord',
#   'Country': 'NO',
#   'Lat': 70.9457,
#   'Lng': 27.3465,
#   'Max Temp': 32,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 23.02,
#   'Date': '2021-04-12 17:27:51',
#   'Current Descripion': 'light snow'},
#  {'City': 'San Felipe',
#   'Country': 'VE',
#   'Lat': 10.3399,
#   'Lng': -68.7425,
#   'Max Temp': 88.48,
#   'Humidity': 51,
#   'Cloudiness': 86,
#   'Wind Speed': 5.97,
#   'Date': '2021-04-12 17:27:51',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Bam',
#   'Country': 'IR',
#   'Lat': 29.106,
#   'Lng': 58.357,
#   'Max Temp': 77.13,
#   'Humidity': 25,
#   'Cloudiness': 78,
#   'Wind Speed': 11.41,
#   'Date': '2021-04-12 17:27:52',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Dhamrai',
#   'Country': 'BD',
#   'Lat': 23.9202,
#   'Lng': 90.2109,
#   'Max Temp': 86,
#   'Humidity': 58,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:27:52',
#   'Current Descripion': 'haze'},
#  {'City': 'Harper',
#   'Country': 'LR',
#   'Lat': 4.375,
#   'Lng': -7.7169,
#   'Max Temp': 83.75,
#   'Humidity': 75,
#   'Cloudiness': 45,
#   'Wind Speed': 8.55,
#   'Date': '2021-04-12 17:27:52',
#   'Current Descripion': 'light rain'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 87.8,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:27:53',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Mattawa',
#   'Country': 'US',
#   'Lat': 46.7379,
#   'Lng': -119.9028,
#   'Max Temp': 41,
#   'Humidity': 39,
#   'Cloudiness': 77,
#   'Wind Speed': 18.01,
#   'Date': '2021-04-12 17:27:53',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Isangel',
#   'Country': 'VU',
#   'Lat': -19.55,
#   'Lng': 169.2667,
#   'Max Temp': 77.41,
#   'Humidity': 84,
#   'Cloudiness': 79,
#   'Wind Speed': 3.38,
#   'Date': '2021-04-12 17:27:53',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Castleblayney',
#   'Country': 'IE',
#   'Lat': 54.1167,
#   'Lng': -6.7333,
#   'Max Temp': 46,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 4,
#   'Date': '2021-04-12 17:27:54',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Yangcun',
#   'Country': 'CN',
#   'Lat': 39.3639,
#   'Lng': 117.0603,
#   'Max Temp': 50,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 20.13,
#   'Date': '2021-04-12 17:27:54',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Entre Rios',
#   'Country': 'BR',
#   'Lat': -11.9419,
#   'Lng': -38.0844,
#   'Max Temp': 86.61,
#   'Humidity': 48,
#   'Cloudiness': 88,
#   'Wind Speed': 9.01,
#   'Date': '2021-04-12 17:27:54',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Manono',
#   'Country': 'CD',
#   'Lat': -7.3,
#   'Lng': 27.4167,
#   'Max Temp': 71.06,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.47,
#   'Date': '2021-04-12 17:27:55',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Sheridan',
#   'Country': 'US',
#   'Lat': 44.8333,
#   'Lng': -106.9173,
#   'Max Temp': 36,
#   'Humidity': 69,
#   'Cloudiness': 90,
#   'Wind Speed': 20.71,
#   'Date': '2021-04-12 17:27:55',
#   'Current Descripion': 'light snow'},
#  {'City': 'Mehndawal',
#   'Country': 'IN',
#   'Lat': 26.9753,
#   'Lng': 83.1117,
#   'Max Temp': 84.81,
#   'Humidity': 8,
#   'Cloudiness': 0,
#   'Wind Speed': 7.23,
#   'Date': '2021-04-12 17:27:56',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Chara',
#   'Country': 'RU',
#   'Lat': 56.9064,
#   'Lng': 118.2631,
#   'Max Temp': -0.78,
#   'Humidity': 75,
#   'Cloudiness': 41,
#   'Wind Speed': 2.71,
#   'Date': '2021-04-12 17:27:56',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Sindal',
#   'Country': 'DK',
#   'Lat': 57.4712,
#   'Lng': 10.2031,
#   'Max Temp': 42.8,
#   'Humidity': 70,
#   'Cloudiness': 45,
#   'Wind Speed': 19.57,
#   'Date': '2021-04-12 17:27:57',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Evinayong',
#   'Country': 'GQ',
#   'Lat': 1.4368,
#   'Lng': 10.5512,
#   'Max Temp': 74.89,
#   'Humidity': 85,
#   'Cloudiness': 84,
#   'Wind Speed': 3.09,
#   'Date': '2021-04-12 17:27:57',
#   'Current Descripion': 'light rain'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -23.69,
#   'Humidity': 83,
#   'Cloudiness': 72,
#   'Wind Speed': 4.23,
#   'Date': '2021-04-12 17:27:58',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Mineiros',
#   'Country': 'BR',
#   'Lat': -17.5694,
#   'Lng': -52.5511,
#   'Max Temp': 84.58,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 3.49,
#   'Date': '2021-04-12 17:27:58',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Caceres',
#   'Country': 'ES',
#   'Lat': 39.522,
#   'Lng': -6.3748,
#   'Max Temp': 66,
#   'Humidity': 56,
#   'Cloudiness': 82,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 17:27:59',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Veraval',
#   'Country': 'IN',
#   'Lat': 20.9,
#   'Lng': 70.3667,
#   'Max Temp': 81.19,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 11.68,
#   'Date': '2021-04-12 17:27:59',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Bonfim',
#   'Country': 'BR',
#   'Lat': 3.0833,
#   'Lng': -59.95,
#   'Max Temp': 83.77,
#   'Humidity': 63,
#   'Cloudiness': 58,
#   'Wind Speed': 4.34,
#   'Date': '2021-04-12 17:27:59',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Tooele',
#   'Country': 'US',
#   'Lat': 40.5308,
#   'Lng': -112.2983,
#   'Max Temp': 44.01,
#   'Humidity': 52,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:28:00',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Nhulunbuy',
#   'Country': 'AU',
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 74,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 17:28:01',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Rawlins',
#   'Country': 'US',
#   'Lat': 41.7911,
#   'Lng': -107.2387,
#   'Max Temp': 30.2,
#   'Humidity': 51,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 17:26:26',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Danville',
#   'Country': 'US',
#   'Lat': 36.586,
#   'Lng': -79.395,
#   'Max Temp': 73.99,
#   'Humidity': 31,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:28:01',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Chamba',
#   'Country': 'IN',
#   'Lat': 32.5667,
#   'Lng': 76.1333,
#   'Max Temp': 61.9,
#   'Humidity': 55,
#   'Cloudiness': 51,
#   'Wind Speed': 10.49,
#   'Date': '2021-04-12 17:28:01',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Kloulklubed',
#   'Country': 'PW',
#   'Lat': 7.0419,
#   'Lng': 134.2556,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:28:02',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Charleston',
#   'Country': 'US',
#   'Lat': 32.7766,
#   'Lng': -79.9309,
#   'Max Temp': 81,
#   'Humidity': 22,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:27:00',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Southbridge',
#   'Country': 'US',
#   'Lat': 42.0751,
#   'Lng': -72.0334,
#   'Max Temp': 48,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 3,
#   'Date': '2021-04-12 17:24:40',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Vilyuysk',
#   'Country': 'RU',
#   'Lat': 63.7553,
#   'Lng': 121.6247,
#   'Max Temp': -8.1,
#   'Humidity': 100,
#   'Cloudiness': 78,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:28:03',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Petropavlovka',
#   'Country': 'RU',
#   'Lat': 50.6114,
#   'Lng': 105.3196,
#   'Max Temp': 32.18,
#   'Humidity': 52,
#   'Cloudiness': 86,
#   'Wind Speed': 4.7,
#   'Date': '2021-04-12 17:28:03',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Victoria Point',
#   'Country': 'AU',
#   'Lat': -27.5833,
#   'Lng': 153.3,
#   'Max Temp': 64,
#   'Humidity': 63,
#   'Cloudiness': 8,
#   'Wind Speed': 1.01,
#   'Date': '2021-04-12 17:28:03',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 50.7,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 4.74,
#   'Date': '2021-04-12 17:28:04',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Ibotirama',
#   'Country': 'BR',
#   'Lat': -12.1853,
#   'Lng': -43.2206,
#   'Max Temp': 92.88,
#   'Humidity': 32,
#   'Cloudiness': 84,
#   'Wind Speed': 2.17,
#   'Date': '2021-04-12 17:28:04',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Oxford',
#   'Country': 'GB',
#   'Lat': 51.7522,
#   'Lng': -1.256,
#   'Max Temp': 48.99,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:24:18',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Champerico',
#   'Country': 'GT',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:28:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Muros',
#   'Country': 'ES',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 66,
#   'Humidity': 48,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:28:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Makakilo City',
#   'Country': 'US',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 68,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 6.17,
#   'Date': '2021-04-12 17:28:05',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Sorland',
#   'Country': 'NO',
#   'Lat': 67.667,
#   'Lng': 12.6934,
#   'Max Temp': 35.6,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 10.29,
#   'Date': '2021-04-12 17:28:06',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Anaconda',
#   'Country': 'US',
#   'Lat': 46.1285,
#   'Lng': -112.9423,
#   'Max Temp': 26.6,
#   'Humidity': 50,
#   'Cloudiness': 90,
#   'Wind Speed': 6.6,
#   'Date': '2021-04-12 17:28:07',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Versmold',
#   'Country': 'DE',
#   'Lat': 52.05,
#   'Lng': 8.15,
#   'Max Temp': 41,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:25:22',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Sikasso',
#   'Country': 'ML',
#   'Lat': 10.9167,
#   'Lng': -7,
#   'Max Temp': 105.64,
#   'Humidity': 12,
#   'Cloudiness': 9,
#   'Wind Speed': 6.69,
#   'Date': '2021-04-12 17:28:07',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Kamenka',
#   'Country': 'RU',
#   'Lat': 51.3223,
#   'Lng': 42.7678,
#   'Max Temp': 57,
#   'Humidity': 50,
#   'Cloudiness': 71,
#   'Wind Speed': 9.8,
#   'Date': '2021-04-12 17:28:08',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Karacakoy',
#   'Country': 'TR',
#   'Lat': 41.4029,
#   'Lng': 28.3834,
#   'Max Temp': 51.01,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:28:08',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Shishou',
#   'Country': 'CN',
#   'Lat': 29.7226,
#   'Lng': 112.419,
#   'Max Temp': 60.19,
#   'Humidity': 87,
#   'Cloudiness': 86,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 17:28:08',
#   'Current Descripion': 'light rain'},
#  {'City': 'Gorin',
#   'Country': 'RU',
#   'Lat': 51.1983,
#   'Lng': 136.6669,
#   'Max Temp': 22.14,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.54,
#   'Date': '2021-04-12 17:28:09',
#   'Current Descripion': 'light snow'},
#  {'City': 'Poso',
#   'Country': 'ID',
#   'Lat': -1.3959,
#   'Lng': 120.7524,
#   'Max Temp': 79,
#   'Humidity': 79,
#   'Cloudiness': 92,
#   'Wind Speed': 4.32,
#   'Date': '2021-04-12 17:28:09',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Angoche',
#   'Country': 'MZ',
#   'Lat': -16.2325,
#   'Lng': 39.9086,
#   'Max Temp': 78.71,
#   'Humidity': 79,
#   'Cloudiness': 90,
#   'Wind Speed': 9.44,
#   'Date': '2021-04-12 17:28:09',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Araouane',
#   'Country': 'ML',
#   'Lat': 18.9048,
#   'Lng': -3.5265,
#   'Max Temp': 105.3,
#   'Humidity': 5,
#   'Cloudiness': 0,
#   'Wind Speed': 6.42,
#   'Date': '2021-04-12 17:27:33',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Mandan',
#   'Country': 'US',
#   'Lat': 46.8267,
#   'Lng': -100.8896,
#   'Max Temp': 33.8,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 24.16,
#   'Date': '2021-04-12 17:28:10',
#   'Current Descripion': 'light snow'},
#  {'City': 'Toppenish',
#   'Country': 'US',
#   'Lat': 46.3774,
#   'Lng': -120.3087,
#   'Max Temp': 51.01,
#   'Humidity': 35,
#   'Cloudiness': 80,
#   'Wind Speed': 3.29,
#   'Date': '2021-04-12 17:28:11',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Sturgeon Falls',
#   'Country': 'CA',
#   'Lat': 46.3646,
#   'Lng': -79.9326,
#   'Max Temp': 57.2,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Date': '2021-04-12 17:28:11',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Praia Da Vitoria',
#   'Country': 'PT',
#   'Lat': 38.7333,
#   'Lng': -27.0667,
#   'Max Temp': 64.99,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 21.25,
#   'Date': '2021-04-12 17:28:11',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Gat',
#   'Country': 'IL',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 60.01,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 7.96,
#   'Date': '2021-04-12 17:28:12',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Semnan',
#   'Country': 'IR',
#   'Lat': 35.5729,
#   'Lng': 53.3971,
#   'Max Temp': 69.6,
#   'Humidity': 28,
#   'Cloudiness': 45,
#   'Wind Speed': 4.41,
#   'Date': '2021-04-12 17:24:21',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Bac Lieu',
#   'Country': 'VN',
#   'Lat': 9.285,
#   'Lng': 105.7244,
#   'Max Temp': 81.95,
#   'Humidity': 79,
#   'Cloudiness': 53,
#   'Wind Speed': 10.87,
#   'Date': '2021-04-12 17:28:13',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Darhan',
#   'Country': 'MN',
#   'Lat': 49.4867,
#   'Lng': 105.9228,
#   'Max Temp': 31.91,
#   'Humidity': 51,
#   'Cloudiness': 78,
#   'Wind Speed': 2.98,
#   'Date': '2021-04-12 17:28:13',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Adamas',
#   'Country': 'GR',
#   'Lat': 36.7333,
#   'Lng': 24.4333,
#   'Max Temp': 57.2,
#   'Humidity': 44,
#   'Cloudiness': 2,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:28:14',
#   'Current Descripion': 'clear sky'},
#  {'City': 'Lyubim',
#   'Country': 'RU',
#   'Lat': 58.3625,
#   'Lng': 40.6843,
#   'Max Temp': 46.51,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 8.32,
#   'Date': '2021-04-12 17:28:15',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Wencheng',
#   'Country': 'CN',
#   'Lat': 33.0559,
#   'Lng': 113.7978,
#   'Max Temp': 60.35,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 5.86,
#   'Date': '2021-04-12 17:28:15',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Agirish',
#   'Country': 'RU',
#   'Lat': 61.9247,
#   'Lng': 63.0231,
#   'Max Temp': 34.61,
#   'Humidity': 83,
#   'Cloudiness': 34,
#   'Wind Speed': 10.25,
#   'Date': '2021-04-12 17:28:15',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Orange',
#   'Country': 'US',
#   'Lat': 33.7,
#   'Lng': -117.7675,
#   'Max Temp': 63,
#   'Humidity': 72,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:28:16',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Santo Domingo',
#   'Country': 'DO',
#   'Lat': 18.5001,
#   'Lng': -69.9886,
#   'Max Temp': 86,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:26:02',
#   'Current Descripion': 'broken clouds'},
#  {'City': 'Puerto Carreno',
#   'Country': 'CO',
#   'Lat': 6.189,
#   'Lng': -67.4859,
#   'Max Temp': 83.23,
#   'Humidity': 64,
#   'Cloudiness': 100,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 17:28:16',
#   'Current Descripion': 'overcast clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 83.77,
#   'Humidity': 57,
#   'Cloudiness': 32,
#   'Wind Speed': 5.55,
#   'Date': '2021-04-12 17:28:17',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Callaway',
#   'Country': 'US',
#   'Lat': 30.153,
#   'Lng': -85.5699,
#   'Max Temp': 82,
#   'Humidity': 33,
#   'Cloudiness': 40,
#   'Wind Speed': 4.5,
#   'Date': '2021-04-12 17:28:17',
#   'Current Descripion': 'scattered clouds'},
#  {'City': 'Mandera',
#   'Country': 'KE',
#   'Lat': 3.9366,
#   'Lng': 41.867,
#   'Max Temp': 89.01,
#   'Humidity': 44,
#   'Cloudiness': 99,
#   'Wind Speed': 11.34,
#   'Date': '2021-04-12 17:28:17',
#   'Current Descripion': 'overcast clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Luwuk      ID  -0.9516  122.7875     76.80        85          20
# 1       Vaini      TO -21.2000 -175.2000     71.60        88          20
# 2    Saldanha      ZA -33.0117   17.9442     73.40        49         100
# 3       Airai      TL  -8.9266  125.4092     56.91        83          83
# 4  Itupiranga      BR  -5.1347  -49.3267     93.20        59          40
# 5      Hobart      AU -42.8794  147.3294     48.20        93          75
# 6     Ushuaia      AR -54.8000  -68.3000     50.00        40          40
# 7    Maragogi      BR  -9.0122  -35.2225     82.83        70          96
# 8     Mataura      NZ -46.1927  168.8643     48.99        94          98
# 9  Bredasdorp      ZA -34.5322   20.0403     66.20        82          95
#
#    Wind Speed                 Date Current Descripion
# 0        2.35  2021-04-12 17:23:44         few clouds
# 1        5.75  2021-04-12 17:23:44         few clouds
# 2        9.22  2021-04-12 17:20:02    overcast clouds
# 3        2.21  2021-04-12 17:23:45      broken clouds
# 4        6.91  2021-04-12 17:23:37   scattered clouds
# 5        5.75  2021-04-12 17:20:23      broken clouds
# 6        8.05  2021-04-12 17:23:46   scattered clouds
# 7        7.92  2021-04-12 17:23:46    overcast clouds
# 8        1.99  2021-04-12 17:23:47    overcast clouds
# 9        8.05  2021-04-12 17:23:47    overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
