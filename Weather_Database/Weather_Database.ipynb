# %%
# Import the random module.
import random

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# (Step 3) Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Import citipy module.
from citipy import citipy

# %%
# (Step 4) Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
city
# Out:
# 'ushuaia'

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# (Step 5) Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e5437bdbf0f856a34296c9a6e740f787

# %%
# Create an endpoint URL for a city.
#city_url = url + "&q=" + "Boston"
#print(city_url)

# %%
# (Step 6) Loop through all the cities in the list and use for-except to work around potential

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.    
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Date": city_date,
                          "Current Description" : city_desc,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | puerto baquerizo moreno
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | hay river
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | tilichiki
# Processing Record 9 of Set 1 | moerai
# Processing Record 10 of Set 1 | kavieng
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | erbaa
# Processing Record 13 of Set 1 | mar del plata
# Processing Record 14 of Set 1 | karratha
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | kanye
# Processing Record 17 of Set 1 | ribeira grande
# Processing Record 18 of Set 1 | chegdomyn
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | chernyshevskiy
# Processing Record 21 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | rognan
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | lebu
# Processing Record 26 of Set 1 | codajas
# Processing Record 27 of Set 1 | hobyo
# Processing Record 28 of Set 1 | pacific grove
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | nouadhibou
# Processing Record 32 of Set 1 | faanui
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | beloha
# Processing Record 35 of Set 1 | sungairaya
# Processing Record 36 of Set 1 | saskylakh
# Processing Record 37 of Set 1 | oistins
# Processing Record 38 of Set 1 | magdagachi
# Processing Record 39 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 1 | lima
# Processing Record 41 of Set 1 | norman wells
# Processing Record 42 of Set 1 | yerbogachen
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | butaritari
# Processing Record 45 of Set 1 | san patricio
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 1 | fortuna
# Processing Record 49 of Set 1 | lazaro cardenas
# Processing Record 50 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 2 of Set 2 | mahebourg
# Processing Record 3 of Set 2 | atuona
# Processing Record 4 of Set 2 | kushikino
# Processing Record 5 of Set 2 | namibe
# Processing Record 6 of Set 2 | bilibino
# Processing Record 7 of Set 2 | waipawa
# Processing Record 8 of Set 2 | alexandria
# Processing Record 9 of Set 2 | cape town
# Processing Record 10 of Set 2 | qaanaaq
# Processing Record 11 of Set 2 | acari
# Processing Record 12 of Set 2 | port hardy
# Processing Record 13 of Set 2 | sur
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | bonthe
# Processing Record 16 of Set 2 | turkistan
# Processing Record 17 of Set 2 | thompson
# Processing Record 18 of Set 2 | pho chai
# Processing Record 19 of Set 2 | santa lucia
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | carnarvon
# Processing Record 23 of Set 2 | mount gambier
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | albany
# Processing Record 26 of Set 2 | ballina
# Processing Record 27 of Set 2 | hokitika
# Processing Record 28 of Set 2 | fremont
# Processing Record 29 of Set 2 | hualmay
# Processing Record 30 of Set 2 | batemans bay
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 34 of Set 2 | maple creek
# Processing Record 35 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 2 | namatanai
# Processing Record 37 of Set 2 | abu samrah
# Processing Record 38 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 2 | qarayeri
# Processing Record 40 of Set 2 | sao filipe
# Processing Record 41 of Set 2 | okha
# Processing Record 42 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 43 of Set 2 | keetmanshoop
# Processing Record 44 of Set 2 | puerto del rosario
# Processing Record 45 of Set 2 | baghdad
# Processing Record 46 of Set 2 | dukat
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 2 | alta floresta
# Processing Record 50 of Set 2 | nadym
# Processing Record 1 of Set 3 | sistranda
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | ramygala
# Processing Record 4 of Set 3 | cap malheureux
# Processing Record 5 of Set 3 | cayenne
# Processing Record 6 of Set 3 | lorengau
# Processing Record 7 of Set 3 | necochea
# Processing Record 8 of Set 3 | saint-philippe
# Processing Record 9 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 3 | whitehorse
# Processing Record 11 of Set 3 | linchuan
# City not found. Skipping...
# Processing Record 12 of Set 3 | borogontsy
# Processing Record 13 of Set 3 | teya
# Processing Record 14 of Set 3 | richards bay
# Processing Record 15 of Set 3 | haines junction
# Processing Record 16 of Set 3 | los llanos de aridane
# Processing Record 17 of Set 3 | eganville
# Processing Record 18 of Set 3 | chokurdakh
# Processing Record 19 of Set 3 | chuy
# Processing Record 20 of Set 3 | gizo
# Processing Record 21 of Set 3 | koslan
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | prince rupert
# Processing Record 24 of Set 3 | vaini
# Processing Record 25 of Set 3 | bandarbeyla
# Processing Record 26 of Set 3 | utrecht
# Processing Record 27 of Set 3 | puerto cabezas
# Processing Record 28 of Set 3 | road town
# Processing Record 29 of Set 3 | ponta do sol
# Processing Record 30 of Set 3 | vila franca do campo
# Processing Record 31 of Set 3 | muromtsevo
# Processing Record 32 of Set 3 | port-gentil
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | pevek
# Processing Record 35 of Set 3 | hithadhoo
# Processing Record 36 of Set 3 | narsaq
# Processing Record 37 of Set 3 | iqaluit
# Processing Record 38 of Set 3 | mergui
# City not found. Skipping...
# Processing Record 39 of Set 3 | hambantota
# Processing Record 40 of Set 3 | new norfolk
# Processing Record 41 of Set 3 | kampot
# Processing Record 42 of Set 3 | huilong
# Processing Record 43 of Set 3 | valdivia
# Processing Record 44 of Set 3 | te anau
# Processing Record 45 of Set 3 | clyde river
# Processing Record 46 of Set 3 | georgiyevskoye
# Processing Record 47 of Set 3 | santo antonio do ica
# Processing Record 48 of Set 3 | mataura
# Processing Record 49 of Set 3 | vientiane
# Processing Record 50 of Set 3 | monrovia
# Processing Record 1 of Set 4 | ixtapa
# Processing Record 2 of Set 4 | zhicheng
# Processing Record 3 of Set 4 | kathu
# Processing Record 4 of Set 4 | puerto ayora
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | tautira
# Processing Record 7 of Set 4 | sakakah
# Processing Record 8 of Set 4 | lesnoy
# Processing Record 9 of Set 4 | burriana
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | lokosovo
# Processing Record 12 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 4 | shakhtinsk
# Processing Record 14 of Set 4 | larsnes
# Processing Record 15 of Set 4 | tasiilaq
# Processing Record 16 of Set 4 | ahipara
# Processing Record 17 of Set 4 | eureka
# Processing Record 18 of Set 4 | dubbo
# Processing Record 19 of Set 4 | kandalaksha
# Processing Record 20 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 21 of Set 4 | pierre
# Processing Record 22 of Set 4 | upernavik
# Processing Record 23 of Set 4 | zambrow
# Processing Record 24 of Set 4 | beringovskiy
# Processing Record 25 of Set 4 | lubao
# Processing Record 26 of Set 4 | sire
# Processing Record 27 of Set 4 | foumban
# Processing Record 28 of Set 4 | zhuanghe
# Processing Record 29 of Set 4 | rubiataba
# Processing Record 30 of Set 4 | redwater
# Processing Record 31 of Set 4 | liwale
# Processing Record 32 of Set 4 | stupino
# Processing Record 33 of Set 4 | rio gallegos
# Processing Record 34 of Set 4 | guanare
# Processing Record 35 of Set 4 | bela vista
# Processing Record 36 of Set 4 | ryde
# Processing Record 37 of Set 4 | port elizabeth
# Processing Record 38 of Set 4 | severo-kurilsk
# Processing Record 39 of Set 4 | torbay
# Processing Record 40 of Set 4 | ewa beach
# Processing Record 41 of Set 4 | mudyuga
# City not found. Skipping...
# Processing Record 42 of Set 4 | roald
# Processing Record 43 of Set 4 | kabanjahe
# Processing Record 44 of Set 4 | arlit
# Processing Record 45 of Set 4 | dikson
# Processing Record 46 of Set 4 | mutis
# Processing Record 47 of Set 4 | biak
# Processing Record 48 of Set 4 | victoria
# Processing Record 49 of Set 4 | east london
# Processing Record 50 of Set 4 | hue
# Processing Record 1 of Set 5 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 5 | kiliya
# Processing Record 3 of Set 5 | neuquen
# Processing Record 4 of Set 5 | tomatlan
# Processing Record 5 of Set 5 | la seyne-sur-mer
# Processing Record 6 of Set 5 | nome
# Processing Record 7 of Set 5 | port lincoln
# Processing Record 8 of Set 5 | saint george
# Processing Record 9 of Set 5 | fort william
# Processing Record 10 of Set 5 | puerto princesa
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | kedrovyy
# Processing Record 13 of Set 5 | zhigansk
# Processing Record 14 of Set 5 | henties bay
# Processing Record 15 of Set 5 | srednekolymsk
# Processing Record 16 of Set 5 | gallup
# Processing Record 17 of Set 5 | esperance
# Processing Record 18 of Set 5 | canto do buriti
# Processing Record 19 of Set 5 | tessalit
# Processing Record 20 of Set 5 | arica
# Processing Record 21 of Set 5 | lumding
# Processing Record 22 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 23 of Set 5 | skjervoy
# Processing Record 24 of Set 5 | bayshore gardens
# Processing Record 25 of Set 5 | longyearbyen
# Processing Record 26 of Set 5 | sola
# Processing Record 27 of Set 5 | edosaki
# Processing Record 28 of Set 5 | oussouye
# Processing Record 29 of Set 5 | coquimbo
# Processing Record 30 of Set 5 | porbandar
# Processing Record 31 of Set 5 | tuatapere
# Processing Record 32 of Set 5 | half moon bay
# Processing Record 33 of Set 5 | toftir
# City not found. Skipping...
# Processing Record 34 of Set 5 | bengkulu
# Processing Record 35 of Set 5 | buala
# Processing Record 36 of Set 5 | kurilsk
# Processing Record 37 of Set 5 | batagay-alyta
# Processing Record 38 of Set 5 | bonavista
# Processing Record 39 of Set 5 | rafraf
# Processing Record 40 of Set 5 | saint-augustin
# Processing Record 41 of Set 5 | hami
# Processing Record 42 of Set 5 | santiago tuxtla
# Processing Record 43 of Set 5 | umm kaddadah
# Processing Record 44 of Set 5 | assiniboia
# Processing Record 45 of Set 5 | qaqortoq
# Processing Record 46 of Set 5 | strezhevoy
# Processing Record 47 of Set 5 | alofi
# Processing Record 48 of Set 5 | luwuk
# Processing Record 49 of Set 5 | kalemie
# Processing Record 50 of Set 5 | port macquarie
# Processing Record 1 of Set 6 | hofn
# Processing Record 2 of Set 6 | seymchan
# Processing Record 3 of Set 6 | nabire
# Processing Record 4 of Set 6 | saldanha
# Processing Record 5 of Set 6 | winnemucca
# Processing Record 6 of Set 6 | havoysund
# Processing Record 7 of Set 6 | christchurch
# Processing Record 8 of Set 6 | bambous virieux
# Processing Record 9 of Set 6 | bethel
# Processing Record 10 of Set 6 | batagay
# Processing Record 11 of Set 6 | dongying
# Processing Record 12 of Set 6 | mandalgovi
# Processing Record 13 of Set 6 | kokkola
# Processing Record 14 of Set 6 | ust-nera
# Processing Record 15 of Set 6 | kaitangata
# Processing Record 16 of Set 6 | paita
# Processing Record 17 of Set 6 | yaan
# Processing Record 18 of Set 6 | keelung
# Processing Record 19 of Set 6 | brae
# Processing Record 20 of Set 6 | yar-sale
# Processing Record 21 of Set 6 | kandrian
# Processing Record 22 of Set 6 | calvinia
# Processing Record 23 of Set 6 | fukue
# Processing Record 24 of Set 6 | sibolga
# Processing Record 25 of Set 6 | isangel
# Processing Record 26 of Set 6 | san roque
# Processing Record 27 of Set 6 | wenling
# Processing Record 28 of Set 6 | klaksvik
# Processing Record 29 of Set 6 | sitka
# Processing Record 30 of Set 6 | havre
# Processing Record 31 of Set 6 | cockburn town
# Processing Record 32 of Set 6 | castro
# Processing Record 33 of Set 6 | dabola
# Processing Record 34 of Set 6 | nuuk
# Processing Record 35 of Set 6 | concarneau
# Processing Record 36 of Set 6 | wadi musa
# Processing Record 37 of Set 6 | mayo
# Processing Record 38 of Set 6 | galesong
# Processing Record 39 of Set 6 | yunjinghong
# City not found. Skipping...
# Processing Record 40 of Set 6 | mackay
# Processing Record 41 of Set 6 | pasni
# Processing Record 42 of Set 6 | ormara
# Processing Record 43 of Set 6 | sibu
# Processing Record 44 of Set 6 | turayf
# Processing Record 45 of Set 6 | lavrentiya
# Processing Record 46 of Set 6 | georgetown
# Processing Record 47 of Set 6 | jinxiang
# Processing Record 48 of Set 6 | coihaique
# Processing Record 49 of Set 6 | argos
# Processing Record 50 of Set 6 | lakes entrance
# Processing Record 1 of Set 7 | santarem
# Processing Record 2 of Set 7 | ullapool
# Processing Record 3 of Set 7 | cidreira
# Processing Record 4 of Set 7 | penzance
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | poltavka
# Processing Record 7 of Set 7 | dingle
# Processing Record 8 of Set 7 | robertsport
# Processing Record 9 of Set 7 | garden city
# Processing Record 10 of Set 7 | ouahigouya
# Processing Record 11 of Set 7 | sambava
# Processing Record 12 of Set 7 | hohhot
# Processing Record 13 of Set 7 | san cristobal
# Processing Record 14 of Set 7 | yagoua
# Processing Record 15 of Set 7 | urucara
# Processing Record 16 of Set 7 | iskateley
# Processing Record 17 of Set 7 | itarema
# Processing Record 18 of Set 7 | binga
# Processing Record 19 of Set 7 | riyadh
# Processing Record 20 of Set 7 | malakal
# Processing Record 21 of Set 7 | dzilam gonzalez
# Processing Record 22 of Set 7 | maceio
# Processing Record 23 of Set 7 | huarmey
# Processing Record 24 of Set 7 | rawson
# Processing Record 25 of Set 7 | oranjemund
# Processing Record 26 of Set 7 | japura
# Processing Record 27 of Set 7 | tura
# Processing Record 28 of Set 7 | sao joao da barra
# Processing Record 29 of Set 7 | vestbygda
# City not found. Skipping...
# Processing Record 30 of Set 7 | luderitz
# Processing Record 31 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 32 of Set 7 | korla
# Processing Record 33 of Set 7 | salinas
# Processing Record 34 of Set 7 | tezu
# Processing Record 35 of Set 7 | puerto escondido
# Processing Record 36 of Set 7 | bage
# Processing Record 37 of Set 7 | kudahuvadhoo
# Processing Record 38 of Set 7 | narowal
# Processing Record 39 of Set 7 | chara
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | eyl
# Processing Record 42 of Set 7 | hasaki
# Processing Record 43 of Set 7 | autazes
# Processing Record 44 of Set 7 | bridlington
# Processing Record 45 of Set 7 | muravlenko
# Processing Record 46 of Set 7 | kungurtug
# Processing Record 47 of Set 7 | lewiston
# Processing Record 48 of Set 7 | buta
# Processing Record 49 of Set 7 | sept-iles
# Processing Record 50 of Set 7 | abu dhabi
# Processing Record 1 of Set 8 | goshogawara
# Processing Record 2 of Set 8 | xixiang
# Processing Record 3 of Set 8 | axim
# Processing Record 4 of Set 8 | ngunguru
# Processing Record 5 of Set 8 | onega
# Processing Record 6 of Set 8 | vaitape
# Processing Record 7 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 8 of Set 8 | hammerfest
# Processing Record 9 of Set 8 | alcudia
# Processing Record 10 of Set 8 | boguchar
# Processing Record 11 of Set 8 | hovd
# Processing Record 12 of Set 8 | san quintin
# Processing Record 13 of Set 8 | plettenberg bay
# Processing Record 14 of Set 8 | bongandanga
# Processing Record 15 of Set 8 | saint-pierre
# Processing Record 16 of Set 8 | trelew
# Processing Record 17 of Set 8 | airai
# Processing Record 18 of Set 8 | popondetta
# Processing Record 19 of Set 8 | labuhan
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | impfondo
# Processing Record 22 of Set 8 | codrington
# Processing Record 23 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 8 | canapi
# Processing Record 25 of Set 8 | ayapel
# Processing Record 26 of Set 8 | leningradskiy
# Processing Record 27 of Set 8 | rio grande
# Processing Record 28 of Set 8 | alamosa
# Processing Record 29 of Set 8 | bardiyah
# Processing Record 30 of Set 8 | fairbanks
# Processing Record 31 of Set 8 | hamilton
# Processing Record 32 of Set 8 | culipapa
# City not found. Skipping...
# Processing Record 33 of Set 8 | college
# Processing Record 34 of Set 8 | portland
# Processing Record 35 of Set 8 | zheleznodorozhnyy
# Processing Record 36 of Set 8 | kamyaran
# Processing Record 37 of Set 8 | shambu
# Processing Record 38 of Set 8 | awbari
# Processing Record 39 of Set 8 | acarau
# Processing Record 40 of Set 8 | porto santo
# Processing Record 41 of Set 8 | the valley
# Processing Record 42 of Set 8 | bundaberg
# Processing Record 43 of Set 8 | praia da vitoria
# Processing Record 44 of Set 8 | broome
# Processing Record 45 of Set 8 | benjamin constant
# Processing Record 46 of Set 8 | keti bandar
# Processing Record 47 of Set 8 | yanan
# City not found. Skipping...
# Processing Record 48 of Set 8 | jati
# Processing Record 49 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 50 of Set 8 | staryy nadym
# Processing Record 1 of Set 9 | kruisfontein
# Processing Record 2 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 9 | grand gaube
# Processing Record 4 of Set 9 | smithers
# Processing Record 5 of Set 9 | shebunino
# Processing Record 6 of Set 9 | ponta delgada
# Processing Record 7 of Set 9 | ukiah
# Processing Record 8 of Set 9 | asau
# Processing Record 9 of Set 9 | guadalupe y calvo
# Processing Record 10 of Set 9 | sao francisco
# Processing Record 11 of Set 9 | san francisco
# Processing Record 12 of Set 9 | balintore
# Processing Record 13 of Set 9 | comanesti
# Processing Record 14 of Set 9 | menongue
# Processing Record 15 of Set 9 | constitucion
# Processing Record 16 of Set 9 | deputatskiy
# Processing Record 17 of Set 9 | dongsheng
# Processing Record 18 of Set 9 | pagudpud
# Processing Record 19 of Set 9 | naze
# Processing Record 20 of Set 9 | wajir
# Processing Record 21 of Set 9 | taree
# Processing Record 22 of Set 9 | paamiut
# Processing Record 23 of Set 9 | vila velha
# Processing Record 24 of Set 9 | nishihara
# Processing Record 25 of Set 9 | vardo
# Processing Record 26 of Set 9 | muros
# Processing Record 27 of Set 9 | vuktyl
# Processing Record 28 of Set 9 | ayan
# Processing Record 29 of Set 9 | sulecin
# Processing Record 30 of Set 9 | lompoc
# Processing Record 31 of Set 9 | guatire
# Processing Record 32 of Set 9 | corinto
# Processing Record 33 of Set 9 | marystown
# Processing Record 34 of Set 9 | nortelandia
# Processing Record 35 of Set 9 | hanzhong
# Processing Record 36 of Set 9 | indianola
# Processing Record 37 of Set 9 | tiksi
# Processing Record 38 of Set 9 | nanortalik
# Processing Record 39 of Set 9 | nehe
# Processing Record 40 of Set 9 | shache
# Processing Record 41 of Set 9 | hoyanger
# Processing Record 42 of Set 9 | colquechaca
# Processing Record 43 of Set 9 | kibaya
# Processing Record 44 of Set 9 | arona
# Processing Record 45 of Set 9 | tazovskiy
# Processing Record 46 of Set 9 | luanda
# Processing Record 47 of Set 9 | banja luka
# Processing Record 48 of Set 9 | tabuk
# Processing Record 49 of Set 9 | svetlogorsk
# Processing Record 50 of Set 9 | kahului
# Processing Record 1 of Set 10 | wonthaggi
# Processing Record 2 of Set 10 | rocha
# Processing Record 3 of Set 10 | nioki
# Processing Record 4 of Set 10 | taft
# Processing Record 5 of Set 10 | lakhdenpokhya
# Processing Record 6 of Set 10 | moose factory
# Processing Record 7 of Set 10 | gaya
# Processing Record 8 of Set 10 | tual
# Processing Record 9 of Set 10 | warrnambool
# Processing Record 10 of Set 10 | planaltina
# Processing Record 11 of Set 10 | weinan
# Processing Record 12 of Set 10 | chifeng
# Processing Record 13 of Set 10 | cabra
# Processing Record 14 of Set 10 | praia
# Processing Record 15 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 16 of Set 10 | puerto madryn
# Processing Record 17 of Set 10 | forest grove
# Processing Record 18 of Set 10 | bambanglipuro
# Processing Record 19 of Set 10 | springfield
# Processing Record 20 of Set 10 | mehamn
# Processing Record 21 of Set 10 | iwaki
# Processing Record 22 of Set 10 | marsh harbour
# Processing Record 23 of Set 10 | medvedevo
# Processing Record 24 of Set 10 | sioux lookout
# Processing Record 25 of Set 10 | chadiza
# Processing Record 26 of Set 10 | belyy yar
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | kismayo
# Processing Record 29 of Set 10 | moussoro
# Processing Record 30 of Set 10 | bhayavadar
# Processing Record 31 of Set 10 | rosario
# Processing Record 32 of Set 10 | albion
# Processing Record 33 of Set 10 | faya
# Processing Record 34 of Set 10 | fandriana
# Processing Record 35 of Set 10 | begang
# Processing Record 36 of Set 10 | phalaborwa
# Processing Record 37 of Set 10 | mecca
# Processing Record 38 of Set 10 | yumen
# Processing Record 39 of Set 10 | tunduru
# City not found. Skipping...
# Processing Record 40 of Set 10 | kharp
# Processing Record 41 of Set 10 | shirokiy
# Processing Record 42 of Set 10 | tadine
# Processing Record 43 of Set 10 | kiruna
# Processing Record 44 of Set 10 | salalah
# Processing Record 45 of Set 10 | manaure
# Processing Record 46 of Set 10 | cabo san lucas
# Processing Record 47 of Set 10 | charters towers
# Processing Record 48 of Set 10 | zachagansk
# City not found. Skipping...
# Processing Record 49 of Set 10 | sakhnovshchyna
# Processing Record 50 of Set 10 | pandamatenga
# Processing Record 1 of Set 11 | villa carlos paz
# Processing Record 2 of Set 11 | ambatondrazaka
# Processing Record 3 of Set 11 | guilin
# Processing Record 4 of Set 11 | vizinga
# Processing Record 5 of Set 11 | macapa
# Processing Record 6 of Set 11 | shahpur
# Processing Record 7 of Set 11 | owando
# Processing Record 8 of Set 11 | vila do maio
# Processing Record 9 of Set 11 | darab
# Processing Record 10 of Set 11 | chizhou
# Processing Record 11 of Set 11 | tatui
# Processing Record 12 of Set 11 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 11 | chapaevsk
# Processing Record 14 of Set 11 | hutchinson
# Processing Record 15 of Set 11 | camocim
# Processing Record 16 of Set 11 | kimberley
# Processing Record 17 of Set 11 | paso de los toros
# Processing Record 18 of Set 11 | burgos
# Processing Record 19 of Set 11 | pundaguitan
# Processing Record 20 of Set 11 | flin flon
# Processing Record 21 of Set 11 | sao jose da coroa grande
# Processing Record 22 of Set 11 | matehuala
# Processing Record 23 of Set 11 | pompeu
# Processing Record 24 of Set 11 | pangody
# Processing Record 25 of Set 11 | roebourne
# Processing Record 26 of Set 11 | klyuchi
# Processing Record 27 of Set 11 | les cayes
# Processing Record 28 of Set 11 | colac
# Processing Record 29 of Set 11 | shanting
# Processing Record 30 of Set 11 | mongo
# Processing Record 31 of Set 11 | kavali
# Processing Record 32 of Set 11 | champerico
# Processing Record 33 of Set 11 | maloshuyka
# City not found. Skipping...
# Processing Record 34 of Set 11 | lere
# Processing Record 35 of Set 11 | kainantu
# Processing Record 36 of Set 11 | bulgan
# Processing Record 37 of Set 11 | tokur
# Processing Record 38 of Set 11 | abha
# Processing Record 39 of Set 11 | kijang
# Processing Record 40 of Set 11 | meulaboh
# Processing Record 41 of Set 11 | shepsi
# Processing Record 42 of Set 11 | kilembe
# Processing Record 43 of Set 11 | sarangani
# Processing Record 44 of Set 11 | caravelas
# Processing Record 45 of Set 11 | ust-tsilma
# Processing Record 46 of Set 11 | redmond
# Processing Record 47 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 48 of Set 11 | atar
# Processing Record 49 of Set 11 | jishou
# Processing Record 50 of Set 11 | geraldton
# Processing Record 1 of Set 12 | bathsheba
# Processing Record 2 of Set 12 | bababe
# City not found. Skipping...
# Processing Record 3 of Set 12 | khangarh
# Processing Record 4 of Set 12 | adrar
# Processing Record 5 of Set 12 | lashio
# Processing Record 6 of Set 12 | tyrma
# Processing Record 7 of Set 12 | woodward
# Processing Record 8 of Set 12 | general roca
# Processing Record 9 of Set 12 | ancud
# Processing Record 10 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 11 of Set 12 | kuruman
# Processing Record 12 of Set 12 | opuwo
# Processing Record 13 of Set 12 | niquero
# Processing Record 14 of Set 12 | maragogi
# Processing Record 15 of Set 12 | kulykivka
# Processing Record 16 of Set 12 | primorsk
# Processing Record 17 of Set 12 | gejiu
# Processing Record 18 of Set 12 | bentiu
# Processing Record 19 of Set 12 | kavaratti
# Processing Record 20 of Set 12 | acapulco
# Processing Record 21 of Set 12 | nchelenge
# Processing Record 22 of Set 12 | madera
# Processing Record 23 of Set 12 | gao
# Processing Record 24 of Set 12 | cotonou
# Processing Record 25 of Set 12 | taltal
# Processing Record 26 of Set 12 | stornoway
# Processing Record 27 of Set 12 | cumberland
# Processing Record 28 of Set 12 | abnub
# Processing Record 29 of Set 12 | sedelnikovo
# City not found. Skipping...
# Processing Record 30 of Set 12 | grindavik
# Processing Record 31 of Set 12 | broken hill
# Processing Record 32 of Set 12 | jablah
# Processing Record 33 of Set 12 | ballarat
# Processing Record 34 of Set 12 | santiago
# Processing Record 35 of Set 12 | outjo
# Processing Record 36 of Set 12 | farafangana
# Processing Record 37 of Set 12 | kasaragod
# Processing Record 38 of Set 12 | kilindoni
# Processing Record 39 of Set 12 | kasempa
# Processing Record 40 of Set 12 | myitkyina
# Processing Record 41 of Set 12 | harper
# Processing Record 42 of Set 12 | kurumkan
# Processing Record 43 of Set 12 | den helder
# Processing Record 44 of Set 12 | flinders
# Processing Record 45 of Set 12 | khatassy
# Processing Record 46 of Set 12 | aljezur
# Processing Record 47 of Set 12 | temba
# Processing Record 48 of Set 12 | alytus
# Processing Record 49 of Set 12 | yicheng
# Processing Record 50 of Set 12 | atka
# City not found. Skipping...
# Processing Record 1 of Set 13 | nonoichi
# Processing Record 2 of Set 13 | talnakh
# Processing Record 3 of Set 13 | verkhoyansk
# Processing Record 4 of Set 13 | salta
# Processing Record 5 of Set 13 | port augusta
# Processing Record 6 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 13 | alekseyevka
# Processing Record 8 of Set 13 | carahue
# Processing Record 9 of Set 13 | berbera
# Processing Record 10 of Set 13 | canutama
# Processing Record 11 of Set 13 | ankazoabo
# Processing Record 12 of Set 13 | jodiya
# Processing Record 13 of Set 13 | bud
# Processing Record 14 of Set 13 | tuyen quang
# Processing Record 15 of Set 13 | ouadda
# Processing Record 16 of Set 13 | shenjiamen
# Processing Record 17 of Set 13 | kaseda
# Processing Record 18 of Set 13 | poum
# Processing Record 19 of Set 13 | gladstone
# Processing Record 20 of Set 13 | kloulklubed
# Processing Record 21 of Set 13 | dudinka
# Processing Record 22 of Set 13 | yulara
# Processing Record 23 of Set 13 | moses lake
# Processing Record 24 of Set 13 | haapiti
# Processing Record 25 of Set 13 | westport
# Processing Record 26 of Set 13 | anqing
# Processing Record 27 of Set 13 | copiapo
# Processing Record 28 of Set 13 | berezovyy
# Processing Record 29 of Set 13 | dauphin
# Processing Record 30 of Set 13 | kirovskiy
# Processing Record 31 of Set 13 | dunedin
# Processing Record 32 of Set 13 | jujuy
# City not found. Skipping...
# Processing Record 33 of Set 13 | inverell
# Processing Record 34 of Set 13 | parrita
# Processing Record 35 of Set 13 | vao
# Processing Record 36 of Set 13 | sayula
# Processing Record 37 of Set 13 | gornyy
# Processing Record 38 of Set 13 | unye
# City not found. Skipping...
# Processing Record 39 of Set 13 | pitimbu
# Processing Record 40 of Set 13 | baykit
# Processing Record 41 of Set 13 | shar
# Processing Record 42 of Set 13 | jitra
# Processing Record 43 of Set 13 | laguna
# Processing Record 44 of Set 13 | micheweni
# Processing Record 45 of Set 13 | tunxi
# City not found. Skipping...
# Processing Record 46 of Set 13 | kegayli
# City not found. Skipping...
# Processing Record 47 of Set 13 | seoul
# Processing Record 48 of Set 13 | kralendijk
# Processing Record 49 of Set 13 | araouane
# Processing Record 50 of Set 13 | ostrovnoy
# Processing Record 1 of Set 14 | konstantinovka
# Processing Record 2 of Set 14 | zhanaozen
# Processing Record 3 of Set 14 | katyuzhanka
# Processing Record 4 of Set 14 | todos santos
# Processing Record 5 of Set 14 | palu
# Processing Record 6 of Set 14 | verkhniy avzyan
# Processing Record 7 of Set 14 | biggar
# Processing Record 8 of Set 14 | vanimo
# Processing Record 9 of Set 14 | yining
# Processing Record 10 of Set 14 | urengoy
# Processing Record 11 of Set 14 | wangaratta
# Processing Record 12 of Set 14 | elko
# Processing Record 13 of Set 14 | agadez
# Processing Record 14 of Set 14 | lardos
# Processing Record 15 of Set 14 | ingham
# Processing Record 16 of Set 14 | goure
# Processing Record 17 of Set 14 | matagami
# Processing Record 18 of Set 14 | north bend
# Processing Record 19 of Set 14 | maputo
# Processing Record 20 of Set 14 | aasiaat
# Processing Record 21 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 14 | camacha
# Processing Record 23 of Set 14 | lagoa
# Processing Record 24 of Set 14 | aswan
# Processing Record 25 of Set 14 | tomiya
# Processing Record 26 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 27 of Set 14 | yingcheng
# Processing Record 28 of Set 14 | nerchinsk
# Processing Record 29 of Set 14 | west odessa
# Processing Record 30 of Set 14 | litayen
# City not found. Skipping...
# Processing Record 31 of Set 14 | abong mbang
# Processing Record 32 of Set 14 | podlesnoye
# Processing Record 33 of Set 14 | killybegs
# Processing Record 34 of Set 14 | leshan
# Processing Record 35 of Set 14 | mianwali
# Processing Record 36 of Set 14 | jalu
# Processing Record 37 of Set 14 | manali
# Processing Record 38 of Set 14 | banjar
# Processing Record 39 of Set 14 | umm lajj
# Processing Record 40 of Set 14 | vostok
# Processing Record 41 of Set 14 | enshi
# Processing Record 42 of Set 14 | la asuncion
# Processing Record 43 of Set 14 | awjilah
# Processing Record 44 of Set 14 | inhambane
# Processing Record 45 of Set 14 | lucea
# Processing Record 46 of Set 14 | reyes
# Processing Record 47 of Set 14 | bichena
# Processing Record 48 of Set 14 | mildura
# Processing Record 49 of Set 14 | taoudenni
# Processing Record 50 of Set 14 | husavik
# Processing Record 1 of Set 15 | pecos
# Processing Record 2 of Set 15 | sumbawa
# City not found. Skipping...
# Processing Record 3 of Set 15 | talcahuano
# Processing Record 4 of Set 15 | amahai
# Processing Record 5 of Set 15 | erenhot
# Processing Record 6 of Set 15 | oksfjord
# Processing Record 7 of Set 15 | hollister
# Processing Record 8 of Set 15 | chincha alta
# Processing Record 9 of Set 15 | horasan
# Processing Record 10 of Set 15 | olafsvik
# Processing Record 11 of Set 15 | kudat
# Processing Record 12 of Set 15 | pangnirtung
# Processing Record 13 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 15 | kirensk
# Processing Record 15 of Set 15 | olden
# Processing Record 16 of Set 15 | boyolangu
# Processing Record 17 of Set 15 | maniitsoq
# Processing Record 18 of Set 15 | capul
# Processing Record 19 of Set 15 | omboue
# Processing Record 20 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 15 | udachnyy
# Processing Record 22 of Set 15 | chulym
# Processing Record 23 of Set 15 | lucatan
# City not found. Skipping...
# Processing Record 24 of Set 15 | kazanskaya
# Processing Record 25 of Set 15 | moulmeingyun
# City not found. Skipping...
# Processing Record 26 of Set 15 | ternate
# Processing Record 27 of Set 15 | buchanan
# Processing Record 28 of Set 15 | druzhba
# Processing Record 29 of Set 15 | yauya
# Processing Record 30 of Set 15 | verkhnevilyuysk
# Processing Record 31 of Set 15 | senneterre
# Processing Record 32 of Set 15 | chumikan
# Processing Record 33 of Set 15 | krasnoarmeyskiy
# Processing Record 34 of Set 15 | malanje
# Processing Record 35 of Set 15 | pau dos ferros
# Processing Record 36 of Set 15 | alyangula
# Processing Record 37 of Set 15 | saint helens
# Processing Record 38 of Set 15 | aitape
# Processing Record 39 of Set 15 | muisne
# Processing Record 40 of Set 15 | burns lake
# Processing Record 41 of Set 15 | valleyview
# Processing Record 42 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 43 of Set 15 | hurghada
# Processing Record 44 of Set 15 | west bay
# Processing Record 45 of Set 15 | jiayuguan
# Processing Record 46 of Set 15 | tula
# Processing Record 47 of Set 15 | kropotkin
# Processing Record 48 of Set 15 | natal
# Processing Record 49 of Set 15 | abilene
# Processing Record 50 of Set 15 | vestmannaeyjar
# Processing Record 1 of Set 16 | kawalu
# Processing Record 2 of Set 16 | la ronge
# Processing Record 3 of Set 16 | redlands
# Processing Record 4 of Set 16 | dicabisagan
# Processing Record 5 of Set 16 | annau
# Processing Record 6 of Set 16 | great bend
# Processing Record 7 of Set 16 | kamaishi
# Processing Record 8 of Set 16 | lannion
# Processing Record 9 of Set 16 | okakarara
# Processing Record 10 of Set 16 | kazalinsk
# City not found. Skipping...
# Processing Record 11 of Set 16 | kuah
# Processing Record 12 of Set 16 | cardston
# Processing Record 13 of Set 16 | boa vista
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# check data to make sure all data is pulled correctly
city_data
# Out:
# [{'City': 'Barrow',
#   'Country': 'US',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -11.2,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:01:02',
#   'Current Description': 'few clouds'},
#  {'City': 'Busselton',
#   'Country': 'AU',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 51.01,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 1.01,
#   'Date': '2021-04-12 18:01:03',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Baquerizo Moreno',
#   'Country': 'EC',
#   'Lat': -0.9,
#   'Lng': -89.6,
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:01:03',
#   'Current Description': 'few clouds'},
#  {'City': 'Port Alfred',
#   'Country': 'ZA',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 71.2,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind Speed': 12.8,
#   'Date': '2021-04-12 18:01:03',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hay River',
#   'Country': 'CA',
#   'Lat': 60.8156,
#   'Lng': -115.7999,
#   'Max Temp': 19.4,
#   'Humidity': 45,
#   'Cloudiness': 29,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 18:01:04',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hobart',
#   'Country': 'AU',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 46.99,
#   'Humidity': 93,
#   'Cloudiness': 34,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:58:02',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rikitea',
#   'Country': 'PF',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 78.26,
#   'Humidity': 70,
#   'Cloudiness': 13,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 18:01:05',
#   'Current Description': 'few clouds'},
#  {'City': 'Tilichiki',
#   'Country': 'RU',
#   'Lat': 60.4667,
#   'Lng': 166.1,
#   'Max Temp': -11.63,
#   'Humidity': 94,
#   'Cloudiness': 27,
#   'Wind Speed': 8.39,
#   'Date': '2021-04-12 18:01:05',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Moerai',
#   'Country': 'PF',
#   'Lat': -22.4333,
#   'Lng': -151.3333,
#   'Max Temp': 79.45,
#   'Humidity': 79,
#   'Cloudiness': 96,
#   'Wind Speed': 15.52,
#   'Date': '2021-04-12 18:01:05',
#   'Current Description': 'moderate rain'},
#  {'City': 'Kavieng',
#   'Country': 'PG',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 78.3,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 12.64,
#   'Date': '2021-04-12 18:01:06',
#   'Current Description': 'light rain'},
#  {'City': 'Hermanus',
#   'Country': 'ZA',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 64.99,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Date': '2021-04-12 18:01:06',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Erbaa',
#   'Country': 'TR',
#   'Lat': 40.6689,
#   'Lng': 36.5675,
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:01:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mar Del Plata',
#   'Country': 'AR',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 75.2,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 17:56:10',
#   'Current Description': 'clear sky'},
#  {'City': 'Karratha',
#   'Country': 'AU',
#   'Lat': -20.7377,
#   'Lng': 116.8463,
#   'Max Temp': 82.38,
#   'Humidity': 74,
#   'Cloudiness': 51,
#   'Wind Speed': 9.19,
#   'Date': '2021-04-12 18:01:07',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ushuaia',
#   'Country': 'AR',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 50,
#   'Humidity': 40,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:00:55',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kanye',
#   'Country': 'BW',
#   'Lat': -24.9667,
#   'Lng': 25.3327,
#   'Max Temp': 69.53,
#   'Humidity': 30,
#   'Cloudiness': 0,
#   'Wind Speed': 4.41,
#   'Date': '2021-04-12 18:01:08',
#   'Current Description': 'clear sky'},
#  {'City': 'Ribeira Grande',
#   'Country': 'PT',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:01:08',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chegdomyn',
#   'Country': 'RU',
#   'Lat': 51.1167,
#   'Lng': 133.0167,
#   'Max Temp': 21.56,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 3.51,
#   'Date': '2021-04-12 18:01:09',
#   'Current Description': 'snow'},
#  {'City': 'Kodiak',
#   'Country': 'US',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 5.88,
#   'Date': '2021-04-12 18:01:09',
#   'Current Description': 'clear sky'},
#  {'City': 'Chernyshevskiy',
#   'Country': 'RU',
#   'Lat': 63.0128,
#   'Lng': 112.4714,
#   'Max Temp': 2.55,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 4.18,
#   'Date': '2021-04-12 18:01:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Katsuura',
#   'Country': 'JP',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 57.2,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 18:01:10',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rognan',
#   'Country': 'NO',
#   'Lat': 67.0953,
#   'Lng': 15.3878,
#   'Max Temp': 36,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:01:11',
#   'Current Description': 'few clouds'},
#  {'City': 'Yellowknife',
#   'Country': 'CA',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': 12,
#   'Humidity': 85,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 18:01:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lebu',
#   'Country': 'CL',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 62.89,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 16.08,
#   'Date': '2021-04-12 18:01:11',
#   'Current Description': 'clear sky'},
#  {'City': 'Codajas',
#   'Country': 'BR',
#   'Lat': -3.8367,
#   'Lng': -62.0569,
#   'Max Temp': 89.04,
#   'Humidity': 54,
#   'Cloudiness': 83,
#   'Wind Speed': 3.65,
#   'Date': '2021-04-12 18:01:12',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobyo',
#   'Country': 'SO',
#   'Lat': 5.3505,
#   'Lng': 48.5268,
#   'Max Temp': 82.33,
#   'Humidity': 61,
#   'Cloudiness': 100,
#   'Wind Speed': 10.89,
#   'Date': '2021-04-12 18:01:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pacific Grove',
#   'Country': 'US',
#   'Lat': 36.6177,
#   'Lng': -121.9166,
#   'Max Temp': 53.6,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:13',
#   'Current Description': 'broken clouds'},
#  {'City': 'Punta Arenas',
#   'Country': 'CL',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 50,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 28.77,
#   'Date': '2021-04-12 18:01:13',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kapaa',
#   'Country': 'US',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 66,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Nouadhibou',
#   'Country': 'MR',
#   'Lat': 20.931,
#   'Lng': -17.0347,
#   'Max Temp': 78.8,
#   'Humidity': 44,
#   'Cloudiness': 11,
#   'Wind Speed': 17.27,
#   'Date': '2021-04-12 18:01:14',
#   'Current Description': 'few clouds'},
#  {'City': 'Faanui',
#   'Country': 'PF',
#   'Lat': -16.4833,
#   'Lng': -151.75,
#   'Max Temp': 82.04,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 12.75,
#   'Date': '2021-04-12 18:01:14',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beloha',
#   'Country': 'MG',
#   'Lat': -25.1667,
#   'Lng': 45.05,
#   'Max Temp': 72.77,
#   'Humidity': 80,
#   'Cloudiness': 8,
#   'Wind Speed': 13.24,
#   'Date': '2021-04-12 18:01:15',
#   'Current Description': 'clear sky'},
#  {'City': 'Sungairaya',
#   'Country': 'ID',
#   'Lat': 0.7,
#   'Lng': 108.9,
#   'Max Temp': 78.08,
#   'Humidity': 82,
#   'Cloudiness': 65,
#   'Wind Speed': 2.04,
#   'Date': '2021-04-12 18:01:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saskylakh',
#   'Country': 'RU',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': 15.4,
#   'Humidity': 92,
#   'Cloudiness': 82,
#   'Wind Speed': 10.94,
#   'Date': '2021-04-12 18:01:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Oistins',
#   'Country': 'BB',
#   'Lat': 13.0667,
#   'Lng': -59.5333,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 18.41,
#   'Date': '2021-04-12 17:56:25',
#   'Current Description': 'volcanic ash'},
#  {'City': 'Magdagachi',
#   'Country': 'RU',
#   'Lat': 53.45,
#   'Lng': 125.8,
#   'Max Temp': 8.85,
#   'Humidity': 89,
#   'Cloudiness': 49,
#   'Wind Speed': 5.5,
#   'Date': '2021-04-12 18:01:16',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lima',
#   'Country': 'PE',
#   'Lat': -12.0432,
#   'Lng': -77.0282,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:59:47',
#   'Current Description': 'clear sky'},
#  {'City': 'Norman Wells',
#   'Country': 'CA',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': 10.4,
#   'Humidity': 56,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:01:17',
#   'Current Description': 'broken clouds'},
#  {'City': 'Yerbogachen',
#   'Country': 'RU',
#   'Lat': 61.2767,
#   'Lng': 108.0108,
#   'Max Temp': 19.24,
#   'Humidity': 97,
#   'Cloudiness': 98,
#   'Wind Speed': 5.39,
#   'Date': '2021-04-12 18:01:17',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nikolskoye',
#   'Country': 'RU',
#   'Lat': 59.7035,
#   'Lng': 30.7861,
#   'Max Temp': 59,
#   'Humidity': 33,
#   'Cloudiness': 0,
#   'Wind Speed': 8.95,
#   'Date': '2021-04-12 18:01:18',
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Country': 'KI',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 82.17,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 14.32,
#   'Date': '2021-04-12 18:01:18',
#   'Current Description': 'light rain'},
#  {'City': 'San Patricio',
#   'Country': 'US',
#   'Lat': 28.017,
#   'Lng': -97.5169,
#   'Max Temp': 87.8,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:01:18',
#   'Current Description': 'broken clouds'},
#  {'City': 'Avarua',
#   'Country': 'CK',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 71,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 18:01:19',
#   'Current Description': 'light rain'},
#  {'City': 'Fortuna',
#   'Country': 'US',
#   'Lat': 40.5982,
#   'Lng': -124.1573,
#   'Max Temp': 55,
#   'Humidity': 82,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:01:19',
#   'Current Description': 'clear sky'},
#  {'City': 'Lazaro Cardenas',
#   'Country': 'MX',
#   'Lat': 17.9583,
#   'Lng': -102.2,
#   'Max Temp': 82.13,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 9.51,
#   'Date': '2021-04-12 18:00:02',
#   'Current Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Country': 'MU',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 18:01:21',
#   'Current Description': 'light rain'},
#  {'City': 'Atuona',
#   'Country': 'PF',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 79.56,
#   'Humidity': 79,
#   'Cloudiness': 50,
#   'Wind Speed': 16.35,
#   'Date': '2021-04-12 18:00:54',
#   'Current Description': 'light rain'},
#  {'City': 'Kushikino',
#   'Country': 'JP',
#   'Lat': 31.7167,
#   'Lng': 130.2667,
#   'Max Temp': 60.01,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Date': '2021-04-12 18:01:21',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namibe',
#   'Country': 'AO',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 80.83,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:01:21',
#   'Current Description': 'clear sky'},
#  {'City': 'Bilibino',
#   'Country': 'RU',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -22.83,
#   'Humidity': 83,
#   'Cloudiness': 72,
#   'Wind Speed': 4.27,
#   'Date': '2021-04-12 18:01:22',
#   'Current Description': 'broken clouds'},
#  {'City': 'Waipawa',
#   'Country': 'NZ',
#   'Lat': -41.4122,
#   'Lng': 175.5153,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 75,
#   'Wind Speed': 24.16,
#   'Date': '2021-04-12 18:01:22',
#   'Current Description': 'broken clouds'},
#  {'City': 'Alexandria',
#   'Country': 'EG',
#   'Lat': 31.2156,
#   'Lng': 29.9553,
#   'Max Temp': 60.8,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 17:59:35',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cape Town',
#   'Country': 'ZA',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 66.99,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 17:56:37',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Qaanaaq',
#   'Country': 'GL',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 7.05,
#   'Humidity': 81,
#   'Cloudiness': 75,
#   'Wind Speed': 3.87,
#   'Date': '2021-04-12 18:01:23',
#   'Current Description': 'broken clouds'},
#  {'City': 'Acari',
#   'Country': 'PE',
#   'Lat': -15.4311,
#   'Lng': -74.6158,
#   'Max Temp': 81.59,
#   'Humidity': 55,
#   'Cloudiness': 39,
#   'Wind Speed': 10,
#   'Date': '2021-04-12 18:01:23',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Hardy',
#   'Country': 'CA',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 42.8,
#   'Humidity': 81,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:24',
#   'Current Description': 'few clouds'},
#  {'City': 'Sur',
#   'Country': 'OM',
#   'Lat': 22.5667,
#   'Lng': 59.5289,
#   'Max Temp': 83.5,
#   'Humidity': 57,
#   'Cloudiness': 27,
#   'Wind Speed': 6.38,
#   'Date': '2021-04-12 18:01:24',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ilulissat',
#   'Country': 'GL',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Date': '2021-04-12 18:01:24',
#   'Current Description': 'snow'},
#  {'City': 'Bonthe',
#   'Country': 'SL',
#   'Lat': 7.5264,
#   'Lng': -12.505,
#   'Max Temp': 84.34,
#   'Humidity': 74,
#   'Cloudiness': 43,
#   'Wind Speed': 13.02,
#   'Date': '2021-04-12 18:01:25',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Turkistan',
#   'Country': 'KZ',
#   'Lat': 43,
#   'Lng': 68,
#   'Max Temp': 52.21,
#   'Humidity': 50,
#   'Cloudiness': 24,
#   'Wind Speed': 3.24,
#   'Date': '2021-04-12 18:01:25',
#   'Current Description': 'light rain'},
#  {'City': 'Thompson',
#   'Country': 'CA',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': 21.2,
#   'Humidity': 53,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Date': '2021-04-12 17:57:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pho Chai',
#   'Country': 'TH',
#   'Lat': 16.3283,
#   'Lng': 103.7703,
#   'Max Temp': 88,
#   'Humidity': 99,
#   'Cloudiness': 17,
#   'Wind Speed': 4.21,
#   'Date': '2021-04-12 18:01:26',
#   'Current Description': 'few clouds'},
#  {'City': 'Santa Lucia',
#   'Country': 'ES',
#   'Lat': 27.9117,
#   'Lng': -15.5407,
#   'Max Temp': 72,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Date': '2021-04-12 18:01:26',
#   'Current Description': 'few clouds'},
#  {'City': 'Hilo',
#   'Country': 'US',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 66.99,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:00:21',
#   'Current Description': 'clear sky'},
#  {'City': 'Bluff',
#   'Country': 'NZ',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 50,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 18:01:27',
#   'Current Description': 'light rain'},
#  {'City': 'Carnarvon',
#   'Country': 'AU',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 74.86,
#   'Humidity': 72,
#   'Cloudiness': 83,
#   'Wind Speed': 22.68,
#   'Date': '2021-04-12 18:01:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mount Gambier',
#   'Country': 'AU',
#   'Lat': -37.8333,
#   'Lng': 140.7667,
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 18:01:27',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tuktoyaktuk',
#   'Country': 'CA',
#   'Lat': 69.4541,
#   'Lng': -133.0374,
#   'Max Temp': -5.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:58:37',
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Country': 'US',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 53.01,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 3.89,
#   'Date': '2021-04-12 18:00:12',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ballina',
#   'Country': 'AU',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 51.8,
#   'Humidity': 93,
#   'Cloudiness': 34,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 18:01:28',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hokitika',
#   'Country': 'NZ',
#   'Lat': -42.7167,
#   'Lng': 170.9667,
#   'Max Temp': 56.21,
#   'Humidity': 89,
#   'Cloudiness': 94,
#   'Wind Speed': 8.93,
#   'Date': '2021-04-12 18:01:29',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Fremont',
#   'Country': 'US',
#   'Lat': 37.5483,
#   'Lng': -121.9886,
#   'Max Temp': 64,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:59:07',
#   'Current Description': 'few clouds'},
#  {'City': 'Hualmay',
#   'Country': 'PE',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 73.6,
#   'Humidity': 72,
#   'Cloudiness': 67,
#   'Wind Speed': 7.96,
#   'Date': '2021-04-12 18:01:14',
#   'Current Description': 'broken clouds'},
#  {'City': 'Batemans Bay',
#   'Country': 'AU',
#   'Lat': -35.7167,
#   'Lng': 150.1833,
#   'Max Temp': 51.01,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Date': '2021-04-12 18:01:29',
#   'Current Description': 'clear sky'},
#  {'City': 'Jamestown',
#   'Country': 'US',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 61,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:58:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Maple Creek',
#   'Country': 'CA',
#   'Lat': 49.9168,
#   'Lng': -109.4848,
#   'Max Temp': 35.6,
#   'Humidity': 55,
#   'Cloudiness': 99,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 18:01:30',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namatanai',
#   'Country': 'PG',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 76.41,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 11.14,
#   'Date': '2021-04-12 18:01:31',
#   'Current Description': 'light rain'},
#  {'City': 'Abu Samrah',
#   'Country': 'SY',
#   'Lat': 35.3029,
#   'Lng': 37.1841,
#   'Max Temp': 49.15,
#   'Humidity': 65,
#   'Cloudiness': 97,
#   'Wind Speed': 6.58,
#   'Date': '2021-04-12 18:01:31',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Qarayeri',
#   'Country': 'AZ',
#   'Lat': 40.7886,
#   'Lng': 46.3066,
#   'Max Temp': 62.6,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 25.32,
#   'Date': '2021-04-12 18:01:31',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sao Filipe',
#   'Country': 'CV',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 76.84,
#   'Humidity': 65,
#   'Cloudiness': 36,
#   'Wind Speed': 5.19,
#   'Date': '2021-04-12 18:01:32',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Okha',
#   'Country': 'RU',
#   'Lat': 53.5739,
#   'Lng': 142.9478,
#   'Max Temp': 20.66,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 6.42,
#   'Date': '2021-04-12 18:01:32',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Keetmanshoop',
#   'Country': 'NA',
#   'Lat': -26.5833,
#   'Lng': 18.1333,
#   'Max Temp': 86,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:33',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Del Rosario',
#   'Country': 'ES',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 69.8,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:01:33',
#   'Current Description': 'few clouds'},
#  {'City': 'Baghdad',
#   'Country': 'IQ',
#   'Lat': 33.3406,
#   'Lng': 44.4009,
#   'Max Temp': 69.8,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 17:57:39',
#   'Current Description': 'clear sky'},
#  {'City': 'Dukat',
#   'Country': 'RU',
#   'Lat': 62.55,
#   'Lng': 155.55,
#   'Max Temp': -23.28,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Date': '2021-04-12 18:01:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Khatanga',
#   'Country': 'RU',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': 23.05,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.44,
#   'Date': '2021-04-12 18:01:34',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alta Floresta',
#   'Country': 'BR',
#   'Lat': -9.8756,
#   'Lng': -56.0861,
#   'Max Temp': 91.4,
#   'Humidity': 52,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:00:36',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Nadym',
#   'Country': 'RU',
#   'Lat': 65.5333,
#   'Lng': 72.5167,
#   'Max Temp': 30.45,
#   'Humidity': 80,
#   'Cloudiness': 91,
#   'Wind Speed': 27.67,
#   'Date': '2021-04-12 18:01:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sistranda',
#   'Country': 'NO',
#   'Lat': 63.7256,
#   'Lng': 8.834,
#   'Max Temp': 39.2,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:01:35',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bredasdorp',
#   'Country': 'ZA',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 66.2,
#   'Humidity': 82,
#   'Cloudiness': 96,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:01:36',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ramygala',
#   'Country': 'LT',
#   'Lat': 55.5167,
#   'Lng': 24.3,
#   'Max Temp': 55.4,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:01:36',
#   'Current Description': 'light rain'},
#  {'City': 'Cap Malheureux',
#   'Country': 'MU',
#   'Lat': -19.9842,
#   'Lng': 57.6142,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 18:01:36',
#   'Current Description': 'light rain'},
#  {'City': 'Cayenne',
#   'Country': 'GF',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 18:01:37',
#   'Current Description': 'few clouds'},
#  {'City': 'Lorengau',
#   'Country': 'PG',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 77.47,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 1.59,
#   'Date': '2021-04-12 18:01:37',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Necochea',
#   'Country': 'AR',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 79,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 3,
#   'Date': '2021-04-12 18:01:38',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Philippe',
#   'Country': 'RE',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 78.8,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:01:38',
#   'Current Description': 'light rain'},
#  {'City': 'Whitehorse',
#   'Country': 'CA',
#   'Lat': 60.7161,
#   'Lng': -135.0538,
#   'Max Temp': 32,
#   'Humidity': 69,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Date': '2021-04-12 18:01:38',
#   'Current Description': 'snow'},
#  {'City': 'Borogontsy',
#   'Country': 'RU',
#   'Lat': 62.6683,
#   'Lng': 131.1683,
#   'Max Temp': -7.01,
#   'Humidity': 100,
#   'Cloudiness': 76,
#   'Wind Speed': 1.61,
#   'Date': '2021-04-12 18:01:39',
#   'Current Description': 'broken clouds'},
#  {'City': 'Teya',
#   'Country': 'RU',
#   'Lat': 60.3778,
#   'Lng': 92.6267,
#   'Max Temp': 32.83,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 7.54,
#   'Date': '2021-04-12 18:01:39',
#   'Current Description': 'light snow'},
#  {'City': 'Richards Bay',
#   'Country': 'ZA',
#   'Lat': -28.783,
#   'Lng': 32.0377,
#   'Max Temp': 72.79,
#   'Humidity': 90,
#   'Cloudiness': 17,
#   'Wind Speed': 0.69,
#   'Date': '2021-04-12 18:01:40',
#   'Current Description': 'few clouds'},
#  {'City': 'Haines Junction',
#   'Country': 'CA',
#   'Lat': 60.7522,
#   'Lng': -137.5108,
#   'Max Temp': 37.4,
#   'Humidity': 44,
#   'Cloudiness': 80,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 18:01:40',
#   'Current Description': 'broken clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Country': 'ES',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 73.4,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:01:40',
#   'Current Description': 'clear sky'},
#  {'City': 'Eganville',
#   'Country': 'CA',
#   'Lat': 45.5334,
#   'Lng': -77.0994,
#   'Max Temp': 60.8,
#   'Humidity': 44,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:01:41',
#   'Current Description': 'few clouds'},
#  {'City': 'Chokurdakh',
#   'Country': 'RU',
#   'Lat': 70.6333,
#   'Lng': 147.9167,
#   'Max Temp': 0.01,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 12.53,
#   'Date': '2021-04-12 18:01:41',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chuy',
#   'Country': 'UY',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 69.96,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.97,
#   'Date': '2021-04-12 18:01:42',
#   'Current Description': 'clear sky'},
#  {'City': 'Gizo',
#   'Country': 'SB',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 81.19,
#   'Humidity': 75,
#   'Cloudiness': 48,
#   'Wind Speed': 4.25,
#   'Date': '2021-04-12 18:01:42',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Koslan',
#   'Country': 'RU',
#   'Lat': 63.4564,
#   'Lng': 48.8989,
#   'Max Temp': 40.59,
#   'Humidity': 72,
#   'Cloudiness': 74,
#   'Wind Speed': 9.44,
#   'Date': '2021-04-12 18:01:43',
#   'Current Description': 'broken clouds'},
#  {'City': 'Souillac',
#   'Country': 'MU',
#   'Lat': -20.5167,
#   'Lng': 57.5167,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 18:01:43',
#   'Current Description': 'light rain'},
#  {'City': 'Prince Rupert',
#   'Country': 'CA',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 39.2,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 1.61,
#   'Date': '2021-04-12 18:01:06',
#   'Current Description': 'clear sky'},
#  {'City': 'Vaini',
#   'Country': 'TO',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:01:44',
#   'Current Description': 'few clouds'},
#  {'City': 'Bandarbeyla',
#   'Country': 'SO',
#   'Lat': 9.4942,
#   'Lng': 50.8122,
#   'Max Temp': 80.22,
#   'Humidity': 69,
#   'Cloudiness': 70,
#   'Wind Speed': 9.13,
#   'Date': '2021-04-12 18:01:44',
#   'Current Description': 'broken clouds'},
#  {'City': 'Utrecht',
#   'Country': 'NL',
#   'Lat': 52,
#   'Lng': 5.25,
#   'Max Temp': 43,
#   'Humidity': 74,
#   'Cloudiness': 62,
#   'Wind Speed': 5.01,
#   'Date': '2021-04-12 18:00:46',
#   'Current Description': 'broken clouds'},
#  {'City': 'Puerto Cabezas',
#   'Country': 'NI',
#   'Lat': 14.0351,
#   'Lng': -83.3888,
#   'Max Temp': 86,
#   'Humidity': 79,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:01:45',
#   'Current Description': 'broken clouds'},
#  {'City': 'Road Town',
#   'Country': 'VG',
#   'Lat': 18.4167,
#   'Lng': -64.6167,
#   'Max Temp': 82.4,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 17:58:08',
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Country': 'PT',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 68,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:01:45',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Country': 'PT',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 62.6,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 18:01:46',
#   'Current Description': 'few clouds'},
#  {'City': 'Muromtsevo',
#   'Country': 'RU',
#   'Lat': 56.3724,
#   'Lng': 75.2418,
#   'Max Temp': 35.71,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 6.96,
#   'Date': '2021-04-12 18:01:47',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port-Gentil',
#   'Country': 'GA',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:01:47',
#   'Current Description': 'few clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Country': 'BR',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 93.2,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 18:01:47',
#   'Current Description': 'clear sky'},
#  {'City': 'Pevek',
#   'Country': 'RU',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -24.68,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.97,
#   'Date': '2021-04-12 18:01:48',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hithadhoo',
#   'Country': 'MV',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 83.8,
#   'Humidity': 69,
#   'Cloudiness': 73,
#   'Wind Speed': 9.8,
#   'Date': '2021-04-12 18:01:48',
#   'Current Description': 'broken clouds'},
#  {'City': 'Narsaq',
#   'Country': 'GL',
#   'Lat': 60.9167,
#   'Lng': -46.05,
#   'Max Temp': 44.6,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:48',
#   'Current Description': 'few clouds'},
#  {'City': 'Iqaluit',
#   'Country': 'CA',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 35.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 18:01:49',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hambantota',
#   'Country': 'LK',
#   'Lat': 6.1241,
#   'Lng': 81.1185,
#   'Max Temp': 79.72,
#   'Humidity': 77,
#   'Cloudiness': 51,
#   'Wind Speed': 0.49,
#   'Date': '2021-04-12 18:01:49',
#   'Current Description': 'broken clouds'},
#  {'City': 'New Norfolk',
#   'Country': 'AU',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 46.99,
#   'Humidity': 88,
#   'Cloudiness': 46,
#   'Wind Speed': 2.77,
#   'Date': '2021-04-12 18:01:50',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kampot',
#   'Country': 'KH',
#   'Lat': 10.6167,
#   'Lng': 104.1833,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 18:01:50',
#   'Current Description': 'few clouds'},
#  {'City': 'Huilong',
#   'Country': 'CN',
#   'Lat': 31.8111,
#   'Lng': 121.655,
#   'Max Temp': 61,
#   'Humidity': 96,
#   'Cloudiness': 37,
#   'Wind Speed': 7.38,
#   'Date': '2021-04-12 18:01:51',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Valdivia',
#   'Country': 'CL',
#   'Lat': -39.8142,
#   'Lng': -73.2459,
#   'Max Temp': 68,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 18:01:51',
#   'Current Description': 'broken clouds'},
#  {'City': 'Te Anau',
#   'Country': 'NZ',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 47.19,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 1.43,
#   'Date': '2021-04-12 18:01:51',
#   'Current Description': 'light rain'},
#  {'City': 'Clyde River',
#   'Country': 'CA',
#   'Lat': 70.4692,
#   'Lng': -68.5914,
#   'Max Temp': 23,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Date': '2021-04-12 18:01:52',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Georgiyevskoye',
#   'Country': 'RU',
#   'Lat': 58.731,
#   'Lng': 45.024,
#   'Max Temp': 39.43,
#   'Humidity': 96,
#   'Cloudiness': 69,
#   'Wind Speed': 5.35,
#   'Date': '2021-04-12 18:01:52',
#   'Current Description': 'broken clouds'},
#  {'City': 'Santo Antonio Do Ica',
#   'Country': 'BR',
#   'Lat': -3.1022,
#   'Lng': -67.9397,
#   'Max Temp': 86.02,
#   'Humidity': 60,
#   'Cloudiness': 99,
#   'Wind Speed': 3.96,
#   'Date': '2021-04-12 18:01:53',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Country': 'NZ',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 50,
#   'Humidity': 95,
#   'Cloudiness': 99,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 18:01:53',
#   'Current Description': 'light rain'},
#  {'City': 'Vientiane',
#   'Country': 'LA',
#   'Lat': 17.9667,
#   'Lng': 102.6,
#   'Max Temp': 91,
#   'Humidity': 77,
#   'Cloudiness': 60,
#   'Wind Speed': 2.59,
#   'Date': '2021-04-12 17:59:54',
#   'Current Description': 'broken clouds'},
#  {'City': 'Monrovia',
#   'Country': 'LR',
#   'Lat': 6.3005,
#   'Lng': -10.7969,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:01:54',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ixtapa',
#   'Country': 'MX',
#   'Lat': 20.7,
#   'Lng': -105.2,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 18:01:54',
#   'Current Description': 'clear sky'},
#  {'City': 'Zhicheng',
#   'Country': 'CN',
#   'Lat': 30.2956,
#   'Lng': 111.5047,
#   'Max Temp': 61,
#   'Humidity': 90,
#   'Cloudiness': 98,
#   'Wind Speed': 0.92,
#   'Date': '2021-04-12 18:01:55',
#   'Current Description': 'light rain'},
#  {'City': 'Kathu',
#   'Country': 'TH',
#   'Lat': 7.9178,
#   'Lng': 98.3332,
#   'Max Temp': 87.01,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 1.14,
#   'Date': '2021-04-12 18:01:55',
#   'Current Description': 'few clouds'},
#  {'City': 'Puerto Ayora',
#   'Country': 'EC',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:55',
#   'Current Description': 'light rain'},
#  {'City': 'Port Blair',
#   'Country': 'IN',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 82.56,
#   'Humidity': 75,
#   'Cloudiness': 64,
#   'Wind Speed': 3.58,
#   'Date': '2021-04-12 18:01:56',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tautira',
#   'Country': 'PF',
#   'Lat': -17.7333,
#   'Lng': -149.15,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:56',
#   'Current Description': 'light rain'},
#  {'City': 'Sakakah',
#   'Country': 'SA',
#   'Lat': 29.9697,
#   'Lng': 40.2064,
#   'Max Temp': 69.8,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind Speed': 17.27,
#   'Date': '2021-04-12 18:01:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Lesnoy',
#   'Country': 'RU',
#   'Lat': 57.6198,
#   'Lng': 63.0784,
#   'Max Temp': 37.63,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 5.14,
#   'Date': '2021-04-12 18:01:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Burriana',
#   'Country': 'ES',
#   'Lat': 39.889,
#   'Lng': -0.085,
#   'Max Temp': 57.99,
#   'Humidity': 71,
#   'Cloudiness': 27,
#   'Wind Speed': 7.94,
#   'Date': '2021-04-12 18:01:57',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Provideniya',
#   'Country': 'RU',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 13.44,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 16.46,
#   'Date': '2021-04-12 18:01:58',
#   'Current Description': 'light snow'},
#  {'City': 'Lokosovo',
#   'Country': 'RU',
#   'Lat': 61.1333,
#   'Lng': 74.8167,
#   'Max Temp': 32.11,
#   'Humidity': 87,
#   'Cloudiness': 9,
#   'Wind Speed': 10.42,
#   'Date': '2021-04-12 18:01:58',
#   'Current Description': 'clear sky'},
#  {'City': 'Shakhtinsk',
#   'Country': 'KZ',
#   'Lat': 49.71,
#   'Lng': 72.5872,
#   'Max Temp': 33.8,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 6.71,
#   'Date': '2021-04-12 18:01:59',
#   'Current Description': 'clear sky'},
#  {'City': 'Larsnes',
#   'Country': 'NO',
#   'Lat': 62.2028,
#   'Lng': 5.5773,
#   'Max Temp': 39.2,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:01:59',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tasiilaq',
#   'Country': 'GL',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 30.2,
#   'Humidity': 69,
#   'Cloudiness': 11,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 18:02:00',
#   'Current Description': 'few clouds'},
#  {'City': 'Ahipara',
#   'Country': 'NZ',
#   'Lat': -35.1667,
#   'Lng': 173.1667,
#   'Max Temp': 63.61,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 6.4,
#   'Date': '2021-04-12 18:02:00',
#   'Current Description': 'few clouds'},
#  {'City': 'Eureka',
#   'Country': 'US',
#   'Lat': 40.8021,
#   'Lng': -124.1637,
#   'Max Temp': 55,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Date': '2021-04-12 17:58:07',
#   'Current Description': 'haze'},
#  {'City': 'Dubbo',
#   'Country': 'AU',
#   'Lat': -32.25,
#   'Lng': 148.6167,
#   'Max Temp': 37.4,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:02:01',
#   'Current Description': 'clear sky'},
#  {'City': 'Kandalaksha',
#   'Country': 'RU',
#   'Lat': 67.162,
#   'Lng': 32.4123,
#   'Max Temp': 35.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind Speed': 2.51,
#   'Date': '2021-04-12 18:02:01',
#   'Current Description': 'light snow'},
#  {'City': 'Pierre',
#   'Country': 'US',
#   'Lat': 44.3683,
#   'Lng': -100.351,
#   'Max Temp': 51.01,
#   'Humidity': 42,
#   'Cloudiness': 90,
#   'Wind Speed': 35.68,
#   'Date': '2021-04-12 18:02:02',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Upernavik',
#   'Country': 'GL',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 30.94,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 13.58,
#   'Date': '2021-04-12 18:02:02',
#   'Current Description': 'light snow'},
#  {'City': 'Zambrow',
#   'Country': 'PL',
#   'Lat': 52.9855,
#   'Lng': 22.2432,
#   'Max Temp': 57,
#   'Humidity': 71,
#   'Cloudiness': 100,
#   'Wind Speed': 11.99,
#   'Date': '2021-04-12 17:59:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Beringovskiy',
#   'Country': 'RU',
#   'Lat': 63.05,
#   'Lng': 179.3167,
#   'Max Temp': 7.79,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 26.37,
#   'Date': '2021-04-12 18:02:03',
#   'Current Description': 'light snow'},
#  {'City': 'Lubao',
#   'Country': 'PH',
#   'Lat': 14.9167,
#   'Lng': 120.55,
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 18:02:03',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sire',
#   'Country': 'NG',
#   'Lat': 12.9299,
#   'Lng': 5.2043,
#   'Max Temp': 93.96,
#   'Humidity': 11,
#   'Cloudiness': 0,
#   'Wind Speed': 4.56,
#   'Date': '2021-04-12 18:02:03',
#   'Current Description': 'clear sky'},
#  {'City': 'Foumban',
#   'Country': 'CM',
#   'Lat': 5.7291,
#   'Lng': 10.9001,
#   'Max Temp': 73.85,
#   'Humidity': 59,
#   'Cloudiness': 93,
#   'Wind Speed': 1.9,
#   'Date': '2021-04-12 18:02:04',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Zhuanghe',
#   'Country': 'CN',
#   'Lat': 39.7008,
#   'Lng': 122.9911,
#   'Max Temp': 43,
#   'Humidity': 63,
#   'Cloudiness': 83,
#   'Wind Speed': 8.01,
#   'Date': '2021-04-12 18:02:04',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rubiataba',
#   'Country': 'BR',
#   'Lat': -15.1644,
#   'Lng': -49.8033,
#   'Max Temp': 79,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 0.96,
#   'Date': '2021-04-12 18:02:04',
#   'Current Description': 'broken clouds'},
#  {'City': 'Redwater',
#   'Country': 'US',
#   'Lat': 33.3582,
#   'Lng': -94.2544,
#   'Max Temp': 82.4,
#   'Humidity': 24,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:02:05',
#   'Current Description': 'clear sky'},
#  {'City': 'Liwale',
#   'Country': 'TZ',
#   'Lat': -9.7667,
#   'Lng': 37.9333,
#   'Max Temp': 69.53,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Date': '2021-04-12 18:02:05',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Stupino',
#   'Country': 'RU',
#   'Lat': 54.9008,
#   'Lng': 38.0708,
#   'Max Temp': 51.8,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Date': '2021-04-12 18:01:57',
#   'Current Description': 'clear sky'},
#  {'City': 'Rio Gallegos',
#   'Country': 'AR',
#   'Lat': -51.6226,
#   'Lng': -69.2181,
#   'Max Temp': 59,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 23.02,
#   'Date': '2021-04-12 18:02:05',
#   'Current Description': 'clear sky'},
#  {'City': 'Guanare',
#   'Country': 'VE',
#   'Lat': 9.0418,
#   'Lng': -69.7421,
#   'Max Temp': 82.36,
#   'Humidity': 68,
#   'Cloudiness': 96,
#   'Wind Speed': 8.63,
#   'Date': '2021-04-12 18:02:06',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bela Vista',
#   'Country': 'BR',
#   'Lat': -22.1089,
#   'Lng': -56.5211,
#   'Max Temp': 87.49,
#   'Humidity': 49,
#   'Cloudiness': 84,
#   'Wind Speed': 4.16,
#   'Date': '2021-04-12 18:02:06',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ryde',
#   'Country': 'GB',
#   'Lat': 50.73,
#   'Lng': -1.1621,
#   'Max Temp': 48,
#   'Humidity': 100,
#   'Cloudiness': 97,
#   'Wind Speed': 1.01,
#   'Date': '2021-04-12 18:02:07',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Elizabeth',
#   'Country': 'ZA',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 18:00:49',
#   'Current Description': 'clear sky'},
#  {'City': 'Severo-Kurilsk',
#   'Country': 'RU',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 32.5,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 3.8,
#   'Date': '2021-04-12 18:02:07',
#   'Current Description': 'light snow'},
#  {'City': 'Torbay',
#   'Country': 'CA',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 37,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 18:02:08',
#   'Current Description': 'light rain'},
#  {'City': 'Ewa Beach',
#   'Country': 'US',
#   'Lat': 21.3156,
#   'Lng': -158.0072,
#   'Max Temp': 73.99,
#   'Humidity': 94,
#   'Cloudiness': 1,
#   'Wind Speed': 7.31,
#   'Date': '2021-04-12 18:00:50',
#   'Current Description': 'clear sky'},
#  {'City': 'Roald',
#   'Country': 'NO',
#   'Lat': 62.5833,
#   'Lng': 6.1333,
#   'Max Temp': 37.4,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Date': '2021-04-12 18:02:08',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kabanjahe',
#   'Country': 'ID',
#   'Lat': 3.1001,
#   'Lng': 98.4908,
#   'Max Temp': 63.39,
#   'Humidity': 96,
#   'Cloudiness': 40,
#   'Wind Speed': 1.59,
#   'Date': '2021-04-12 18:02:09',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Arlit',
#   'Country': 'NE',
#   'Lat': 18.7369,
#   'Lng': 7.3853,
#   'Max Temp': 93.2,
#   'Humidity': 5,
#   'Cloudiness': 0,
#   'Wind Speed': 5.14,
#   'Date': '2021-04-12 18:02:09',
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Country': 'RU',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': 25.83,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 18.12,
#   'Date': '2021-04-12 18:02:10',
#   'Current Description': 'light snow'},
#  {'City': 'Mutis',
#   'Country': 'CO',
#   'Lat': 6.2262,
#   'Lng': -77.4044,
#   'Max Temp': 81.61,
#   'Humidity': 83,
#   'Cloudiness': 95,
#   'Wind Speed': 7.36,
#   'Date': '2021-04-12 18:02:10',
#   'Current Description': 'light rain'},
#  {'City': 'Biak',
#   'Country': 'ID',
#   'Lat': -0.9131,
#   'Lng': 122.8766,
#   'Max Temp': 75.43,
#   'Humidity': 83,
#   'Cloudiness': 30,
#   'Wind Speed': 2.08,
#   'Date': '2021-04-12 18:02:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Victoria',
#   'Country': 'HK',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 75,
#   'Humidity': 85,
#   'Cloudiness': 44,
#   'Wind Speed': 4.56,
#   'Date': '2021-04-12 18:00:03',
#   'Current Description': 'scattered clouds'},
#  {'City': 'East London',
#   'Country': 'ZA',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 73.4,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:02:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hue',
#   'Country': 'VN',
#   'Lat': 16.4667,
#   'Lng': 107.6,
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 18:02:11',
#   'Current Description': 'few clouds'},
#  {'City': 'Kiliya',
#   'Country': 'UA',
#   'Lat': 45.4552,
#   'Lng': 29.2637,
#   'Max Temp': 57.2,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:02:12',
#   'Current Description': 'broken clouds'},
#  {'City': 'Neuquen',
#   'Country': 'AR',
#   'Lat': -38.9516,
#   'Lng': -68.0591,
#   'Max Temp': 80.6,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 18:02:13',
#   'Current Description': 'clear sky'},
#  {'City': 'Tomatlan',
#   'Country': 'MX',
#   'Lat': 19.9333,
#   'Lng': -105.25,
#   'Max Temp': 89.35,
#   'Humidity': 33,
#   'Cloudiness': 5,
#   'Wind Speed': 10.02,
#   'Date': '2021-04-12 18:02:13',
#   'Current Description': 'clear sky'},
#  {'City': 'La Seyne-Sur-Mer',
#   'Country': 'FR',
#   'Lat': 43.0982,
#   'Lng': 5.8847,
#   'Max Temp': 55,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind Speed': 8.99,
#   'Date': '2021-04-12 18:02:13',
#   'Current Description': 'clear sky'},
#  {'City': 'Nome',
#   'Country': 'US',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 30.99,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 18:02:14',
#   'Current Description': 'light snow'},
#  {'City': 'Port Lincoln',
#   'Country': 'AU',
#   'Lat': -34.7333,
#   'Lng': 135.8667,
#   'Max Temp': 68.27,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind Speed': 25.97,
#   'Date': '2021-04-12 18:02:14',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saint George',
#   'Country': 'US',
#   'Lat': 37.1041,
#   'Lng': -113.5841,
#   'Max Temp': 70,
#   'Humidity': 15,
#   'Cloudiness': 1,
#   'Wind Speed': 2.28,
#   'Date': '2021-04-12 18:00:04',
#   'Current Description': 'clear sky'},
#  {'City': 'Fort William',
#   'Country': 'GB',
#   'Lat': 56.8165,
#   'Lng': -5.1121,
#   'Max Temp': 45,
#   'Humidity': 63,
#   'Cloudiness': 3,
#   'Wind Speed': 1.99,
#   'Date': '2021-04-12 18:02:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Princesa',
#   'Country': 'PH',
#   'Lat': 9.7392,
#   'Lng': 118.7353,
#   'Max Temp': 77.77,
#   'Humidity': 86,
#   'Cloudiness': 68,
#   'Wind Speed': 3.06,
#   'Date': '2021-04-12 18:02:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cherskiy',
#   'Country': 'RU',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -28.07,
#   'Humidity': 100,
#   'Cloudiness': 30,
#   'Wind Speed': 3.83,
#   'Date': '2021-04-12 18:02:15',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kedrovyy',
#   'Country': 'RU',
#   'Lat': 56.1667,
#   'Lng': 91.8167,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Date': '2021-04-12 18:02:16',
#   'Current Description': 'snow'},
#  {'City': 'Zhigansk',
#   'Country': 'RU',
#   'Lat': 66.7697,
#   'Lng': 123.3711,
#   'Max Temp': 4.06,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 9.01,
#   'Date': '2021-04-12 18:02:16',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Henties Bay',
#   'Country': 'NA',
#   'Lat': -22.116,
#   'Lng': 14.2845,
#   'Max Temp': 77.7,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 9.84,
#   'Date': '2021-04-12 18:02:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Srednekolymsk',
#   'Country': 'RU',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -27.99,
#   'Humidity': 100,
#   'Cloudiness': 44,
#   'Wind Speed': 3,
#   'Date': '2021-04-12 18:02:17',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gallup',
#   'Country': 'US',
#   'Lat': 35.5281,
#   'Lng': -108.7426,
#   'Max Temp': 66.2,
#   'Humidity': 10,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:02:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Esperance',
#   'Country': 'AU',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 57.2,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind Speed': 17.27,
#   'Date': '2021-04-12 18:02:18',
#   'Current Description': 'broken clouds'},
#  {'City': 'Canto Do Buriti',
#   'Country': 'BR',
#   'Lat': -8.11,
#   'Lng': -42.9444,
#   'Max Temp': 91.17,
#   'Humidity': 37,
#   'Cloudiness': 52,
#   'Wind Speed': 6.4,
#   'Date': '2021-04-12 18:02:18',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tessalit',
#   'Country': 'ML',
#   'Lat': 20.1986,
#   'Lng': 1.0114,
#   'Max Temp': 97.18,
#   'Humidity': 7,
#   'Cloudiness': 1,
#   'Wind Speed': 11.9,
#   'Date': '2021-04-12 18:02:18',
#   'Current Description': 'clear sky'},
#  {'City': 'Arica',
#   'Country': 'CL',
#   'Lat': -18.475,
#   'Lng': -70.3042,
#   'Max Temp': 71.6,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 17:57:59',
#   'Current Description': 'clear sky'},
#  {'City': 'Lumding',
#   'Country': 'IN',
#   'Lat': 25.7535,
#   'Lng': 93.1732,
#   'Max Temp': 75.78,
#   'Humidity': 47,
#   'Cloudiness': 17,
#   'Wind Speed': 2.71,
#   'Date': '2021-04-12 18:02:19',
#   'Current Description': 'few clouds'},
#  {'City': 'Skjervoy',
#   'Country': 'NO',
#   'Lat': 70.0311,
#   'Lng': 20.9714,
#   'Max Temp': 33.8,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:02:20',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bayshore Gardens',
#   'Country': 'US',
#   'Lat': 27.4253,
#   'Lng': -82.5904,
#   'Max Temp': 82,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 18:02:20',
#   'Current Description': 'clear sky'},
#  {'City': 'Longyearbyen',
#   'Country': 'SJ',
#   'Lat': 78.2186,
#   'Lng': 15.6401,
#   'Max Temp': 14,
#   'Humidity': 57,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:02:21',
#   'Current Description': 'few clouds'},
#  {'City': 'Sola',
#   'Country': 'VU',
#   'Lat': -13.8833,
#   'Lng': 167.55,
#   'Max Temp': 81.86,
#   'Humidity': 74,
#   'Cloudiness': 97,
#   'Wind Speed': 13.18,
#   'Date': '2021-04-12 18:02:21',
# ...
#   'Lat': -8.19,
#   'Lng': 114.9675,
#   'Max Temp': 76.44,
#   'Humidity': 88,
#   'Cloudiness': 7,
#   'Wind Speed': 4.99,
#   'Date': '2021-04-12 18:05:08',
#   'Current Description': 'clear sky'},
#  {'City': 'Umm Lajj',
#   'Country': 'SA',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 71.56,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 13.31,
#   'Date': '2021-04-12 18:05:08',
#   'Current Description': 'clear sky'},
#  {'City': 'Vostok',
#   'Country': 'RU',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': 43.7,
#   'Humidity': 56,
#   'Cloudiness': 100,
#   'Wind Speed': 10.83,
#   'Date': '2021-04-12 18:05:09',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Enshi',
#   'Country': 'CN',
#   'Lat': 30.3,
#   'Lng': 109.4833,
#   'Max Temp': 60.39,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 0.78,
#   'Date': '2021-04-12 18:05:10',
#   'Current Description': 'light rain'},
#  {'City': 'La Asuncion',
#   'Country': 'VE',
#   'Lat': 11.0333,
#   'Lng': -63.8628,
#   'Max Temp': 81.81,
#   'Humidity': 75,
#   'Cloudiness': 84,
#   'Wind Speed': 6.87,
#   'Date': '2021-04-12 18:05:10',
#   'Current Description': 'broken clouds'},
#  {'City': 'Awjilah',
#   'Country': 'LY',
#   'Lat': 29.1081,
#   'Lng': 21.2869,
#   'Max Temp': 74.12,
#   'Humidity': 9,
#   'Cloudiness': 62,
#   'Wind Speed': 11.65,
#   'Date': '2021-04-12 18:05:10',
#   'Current Description': 'broken clouds'},
#  {'City': 'Inhambane',
#   'Country': 'MZ',
#   'Lat': -23.865,
#   'Lng': 35.3833,
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:05:11',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lucea',
#   'Country': 'JM',
#   'Lat': 18.451,
#   'Lng': -78.1736,
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 18:05:11',
#   'Current Description': 'few clouds'},
#  {'City': 'Reyes',
#   'Country': 'BO',
#   'Lat': -14.3167,
#   'Lng': -67.3833,
#   'Max Temp': 65.86,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 4.59,
#   'Date': '2021-04-12 18:05:12',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bichena',
#   'Country': 'ET',
#   'Lat': 10.45,
#   'Lng': 38.2,
#   'Max Temp': 59.23,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 18:05:12',
#   'Current Description': 'light rain'},
#  {'City': 'Mildura',
#   'Country': 'AU',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Max Temp': 51.8,
#   'Humidity': 54,
#   'Cloudiness': 94,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:05:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taoudenni',
#   'Country': 'ML',
#   'Lat': 22.6783,
#   'Lng': -3.9836,
#   'Max Temp': 100.81,
#   'Humidity': 7,
#   'Cloudiness': 98,
#   'Wind Speed': 5.79,
#   'Date': '2021-04-12 18:05:13',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Husavik',
#   'Country': 'IS',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 48.2,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 18:05:13',
#   'Current Description': 'clear sky'},
#  {'City': 'Pecos',
#   'Country': 'US',
#   'Lat': 31.4229,
#   'Lng': -103.4932,
#   'Max Temp': 68,
#   'Humidity': 22,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Date': '2021-04-12 18:05:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Talcahuano',
#   'Country': 'CL',
#   'Lat': -36.7167,
#   'Lng': -73.1167,
#   'Max Temp': 71.6,
#   'Humidity': 56,
#   'Cloudiness': 0,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:05:14',
#   'Current Description': 'clear sky'},
#  {'City': 'Amahai',
#   'Country': 'ID',
#   'Lat': -3.3333,
#   'Lng': 128.9167,
#   'Max Temp': 82,
#   'Humidity': 92,
#   'Cloudiness': 76,
#   'Wind Speed': 3.27,
#   'Date': '2021-04-12 18:05:15',
#   'Current Description': 'broken clouds'},
#  {'City': 'Erenhot',
#   'Country': 'CN',
#   'Lat': 43.6475,
#   'Lng': 111.9767,
#   'Max Temp': 30.69,
#   'Humidity': 18,
#   'Cloudiness': 4,
#   'Wind Speed': 8.32,
#   'Date': '2021-04-12 18:05:16',
#   'Current Description': 'clear sky'},
#  {'City': 'Oksfjord',
#   'Country': 'NO',
#   'Lat': 70.2396,
#   'Lng': 22.3479,
#   'Max Temp': 32,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:05:16',
#   'Current Description': 'light snow'},
#  {'City': 'Hollister',
#   'Country': 'US',
#   'Lat': 36.8525,
#   'Lng': -121.4016,
#   'Max Temp': 55.4,
#   'Humidity': 76,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 18:03:52',
#   'Current Description': 'clear sky'},
#  {'City': 'Chincha Alta',
#   'Country': 'PE',
#   'Lat': -13.4099,
#   'Lng': -76.1323,
#   'Max Temp': 75.2,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 23.02,
#   'Date': '2021-04-12 18:05:17',
#   'Current Description': 'clear sky'},
#  {'City': 'Horasan',
#   'Country': 'TR',
#   'Lat': 40.0458,
#   'Lng': 42.1728,
#   'Max Temp': 39.34,
#   'Humidity': 71,
#   'Cloudiness': 85,
#   'Wind Speed': 2.13,
#   'Date': '2021-04-12 18:05:17',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Olafsvik',
#   'Country': 'IS',
#   'Lat': 64.8945,
#   'Lng': -23.7142,
#   'Max Temp': 40.84,
#   'Humidity': 78,
#   'Cloudiness': 29,
#   'Wind Speed': 3.78,
#   'Date': '2021-04-12 18:05:17',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kudat',
#   'Country': 'MY',
#   'Lat': 6.8837,
#   'Lng': 116.8477,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 18:05:18',
#   'Current Description': 'few clouds'},
#  {'City': 'Pangnirtung',
#   'Country': 'CA',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 35.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 3.65,
#   'Date': '2021-04-12 18:05:18',
#   'Current Description': 'light rain'},
#  {'City': 'Kirensk',
#   'Country': 'RU',
#   'Lat': 57.7853,
#   'Lng': 108.1119,
#   'Max Temp': 19.89,
#   'Humidity': 98,
#   'Cloudiness': 90,
#   'Wind Speed': 3.96,
#   'Date': '2021-04-12 18:05:19',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Olden',
#   'Country': 'NO',
#   'Lat': 61.8364,
#   'Lng': 6.8064,
#   'Max Temp': 39.2,
#   'Humidity': 60,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:05:20',
#   'Current Description': 'broken clouds'},
#  {'City': 'Boyolangu',
#   'Country': 'ID',
#   'Lat': -8.1181,
#   'Lng': 111.8935,
#   'Max Temp': 75.13,
#   'Humidity': 92,
#   'Cloudiness': 15,
#   'Wind Speed': 1.61,
#   'Date': '2021-04-12 18:05:20',
#   'Current Description': 'few clouds'},
#  {'City': 'Maniitsoq',
#   'Country': 'GL',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 34.59,
#   'Humidity': 76,
#   'Cloudiness': 70,
#   'Wind Speed': 9.84,
#   'Date': '2021-04-12 18:05:20',
#   'Current Description': 'broken clouds'},
#  {'City': 'Capul',
#   'Country': 'PH',
#   'Lat': 12.4237,
#   'Lng': 124.1811,
#   'Max Temp': 79.75,
#   'Humidity': 84,
#   'Cloudiness': 86,
#   'Wind Speed': 11.72,
#   'Date': '2021-04-12 18:05:21',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Omboue',
#   'Country': 'GA',
#   'Lat': -1.5746,
#   'Lng': 9.2618,
#   'Max Temp': 81.05,
#   'Humidity': 82,
#   'Cloudiness': 78,
#   'Wind Speed': 6.38,
#   'Date': '2021-04-12 18:05:21',
#   'Current Description': 'light rain'},
#  {'City': 'Udachnyy',
#   'Country': 'RU',
#   'Lat': 66.4167,
#   'Lng': 112.4,
#   'Max Temp': 12.79,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 8.81,
#   'Date': '2021-04-12 18:05:22',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chulym',
#   'Country': 'RU',
#   'Lat': 55.0997,
#   'Lng': 80.9572,
#   'Max Temp': 32.74,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 8.46,
#   'Date': '2021-04-12 18:05:22',
#   'Current Description': 'light rain'},
#  {'City': 'Kazanskaya',
#   'Country': 'RU',
#   'Lat': 45.4106,
#   'Lng': 40.4361,
#   'Max Temp': 48,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.7,
#   'Date': '2021-04-12 18:05:23',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ternate',
#   'Country': 'ID',
#   'Lat': 0.8,
#   'Lng': 127.4,
#   'Max Temp': 80.19,
#   'Humidity': 82,
#   'Cloudiness': 76,
#   'Wind Speed': 7.99,
#   'Date': '2021-04-12 18:05:23',
#   'Current Description': 'broken clouds'},
#  {'City': 'Buchanan',
#   'Country': 'LR',
#   'Lat': 5.8808,
#   'Lng': -10.0467,
#   'Max Temp': 89.6,
#   'Humidity': 66,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:05:18',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Druzhba',
#   'Country': 'UA',
#   'Lat': 52.0428,
#   'Lng': 33.9453,
#   'Max Temp': 54.21,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 6.17,
#   'Date': '2021-04-12 18:05:24',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yauya',
#   'Country': 'PE',
#   'Lat': -8.9833,
#   'Lng': -77.3,
#   'Max Temp': 59.4,
#   'Humidity': 55,
#   'Cloudiness': 80,
#   'Wind Speed': 5.99,
#   'Date': '2021-04-12 18:05:25',
#   'Current Description': 'light rain'},
#  {'City': 'Verkhnevilyuysk',
#   'Country': 'RU',
#   'Lat': 63.4453,
#   'Lng': 120.3167,
#   'Max Temp': -6.59,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 2.66,
#   'Date': '2021-04-12 18:05:25',
#   'Current Description': 'broken clouds'},
#  {'City': 'Senneterre',
#   'Country': 'CA',
#   'Lat': 48.3835,
#   'Lng': -77.2328,
#   'Max Temp': 55.4,
#   'Humidity': 58,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Date': '2021-04-12 18:05:26',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Chumikan',
#   'Country': 'RU',
#   'Lat': 54.7183,
#   'Lng': 135.315,
#   'Max Temp': 15.44,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 3.71,
#   'Date': '2021-04-12 18:05:26',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Krasnoarmeyskiy',
#   'Country': 'RU',
#   'Lat': 47.0114,
#   'Lng': 42.2072,
#   'Max Temp': 54.27,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 6.8,
#   'Date': '2021-04-12 18:05:26',
#   'Current Description': 'light rain'},
#  {'City': 'Malanje',
#   'Country': 'AO',
#   'Lat': -9.5402,
#   'Lng': 16.341,
#   'Max Temp': 65.17,
#   'Humidity': 92,
#   'Cloudiness': 73,
#   'Wind Speed': 4.21,
#   'Date': '2021-04-12 18:05:27',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pau Dos Ferros',
#   'Country': 'BR',
#   'Lat': -6.1125,
#   'Lng': -38.2063,
#   'Max Temp': 86.85,
#   'Humidity': 55,
#   'Cloudiness': 99,
#   'Wind Speed': 0.74,
#   'Date': '2021-04-12 18:05:27',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alyangula',
#   'Country': 'AU',
#   'Lat': -13.8483,
#   'Lng': 136.4192,
#   'Max Temp': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 22,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 18:05:27',
#   'Current Description': 'few clouds'},
#  {'City': 'Saint Helens',
#   'Country': 'GB',
#   'Lat': 53.45,
#   'Lng': -2.7333,
#   'Max Temp': 48.2,
#   'Humidity': 34,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Date': '2021-04-12 18:05:28',
#   'Current Description': 'few clouds'},
#  {'City': 'Aitape',
#   'Country': 'PG',
#   'Lat': -3.1374,
#   'Lng': 142.3475,
#   'Max Temp': 75.78,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 2.68,
#   'Date': '2021-04-12 18:05:28',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Muisne',
#   'Country': 'EC',
#   'Lat': 0.6,
#   'Lng': -80.0333,
#   'Max Temp': 86,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:05:28',
#   'Current Description': 'broken clouds'},
#  {'City': 'Burns Lake',
#   'Country': 'CA',
#   'Lat': 54.2331,
#   'Lng': -125.7533,
#   'Max Temp': 33.8,
#   'Humidity': 47,
#   'Cloudiness': 9,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 18:05:29',
#   'Current Description': 'clear sky'},
#  {'City': 'Valleyview',
#   'Country': 'CA',
#   'Lat': 55.0667,
#   'Lng': -117.2859,
#   'Max Temp': 33.8,
#   'Humidity': 64,
#   'Cloudiness': 5,
#   'Wind Speed': 2.3,
#   'Date': '2021-04-12 18:04:29',
#   'Current Description': 'clear sky'},
#  {'City': 'Hurghada',
#   'Country': 'EG',
#   'Lat': 27.2574,
#   'Lng': 33.8129,
#   'Max Temp': 69.8,
#   'Humidity': 32,
#   'Cloudiness': 0,
#   'Wind Speed': 19.57,
#   'Date': '2021-04-12 18:05:30',
#   'Current Description': 'clear sky'},
#  {'City': 'West Bay',
#   'Country': 'KY',
#   'Lat': 19.3667,
#   'Lng': -81.4167,
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 12.66,
#   'Date': '2021-04-12 18:05:30',
#   'Current Description': 'few clouds'},
#  {'City': 'Jiayuguan',
#   'Country': 'CN',
#   'Lat': 39.8167,
#   'Lng': 98.3,
#   'Max Temp': 36.37,
#   'Humidity': 56,
#   'Cloudiness': 39,
#   'Wind Speed': 7.83,
#   'Date': '2021-04-12 18:05:31',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tula',
#   'Country': 'RU',
#   'Lat': 54.2044,
#   'Lng': 37.6111,
#   'Max Temp': 52.97,
#   'Humidity': 82,
#   'Cloudiness': 87,
#   'Wind Speed': 11.52,
#   'Date': '2021-04-12 18:05:31',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kropotkin',
#   'Country': 'RU',
#   'Lat': 45.4375,
#   'Lng': 40.5756,
#   'Max Temp': 48,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 4.79,
#   'Date': '2021-04-12 18:05:31',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Natal',
#   'Country': 'BR',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 87.8,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Date': '2021-04-12 18:05:32',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Abilene',
#   'Country': 'US',
#   'Lat': 32.4487,
#   'Lng': -99.7331,
#   'Max Temp': 66.99,
#   'Humidity': 42,
#   'Cloudiness': 1,
#   'Wind Speed': 13.8,
#   'Date': '2021-04-12 18:05:32',
#   'Current Description': 'clear sky'},
#  {'City': 'Vestmannaeyjar',
#   'Country': 'IS',
#   'Lat': 63.4427,
#   'Lng': -20.2734,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 20.71,
#   'Date': '2021-04-12 18:05:32',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kawalu',
#   'Country': 'ID',
#   'Lat': -7.3817,
#   'Lng': 108.2082,
#   'Max Temp': 72.93,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 0.87,
#   'Date': '2021-04-12 18:05:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Ronge',
#   'Country': 'CA',
#   'Lat': 55.1001,
#   'Lng': -105.2842,
#   'Max Temp': 30.2,
#   'Humidity': 43,
#   'Cloudiness': 87,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:05:33',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Redlands',
#   'Country': 'US',
#   'Lat': 34.0556,
#   'Lng': -117.1825,
#   'Max Temp': 64,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 6.2,
#   'Date': '2021-04-12 18:05:34',
#   'Current Description': 'haze'},
#  {'City': 'Dicabisagan',
#   'Country': 'PH',
#   'Lat': 17.0818,
#   'Lng': 122.4157,
#   'Max Temp': 75.87,
#   'Humidity': 90,
#   'Cloudiness': 78,
#   'Wind Speed': 4.16,
#   'Date': '2021-04-12 18:05:34',
#   'Current Description': 'broken clouds'},
#  {'City': 'Annau',
#   'Country': 'TM',
#   'Lat': 37.8876,
#   'Lng': 58.516,
#   'Max Temp': 59,
#   'Humidity': 47,
#   'Cloudiness': 23,
#   'Wind Speed': 4.61,
#   'Date': '2021-04-12 18:05:34',
#   'Current Description': 'few clouds'},
#  {'City': 'Great Bend',
#   'Country': 'US',
#   'Lat': 38.3645,
#   'Lng': -98.7648,
#   'Max Temp': 55,
#   'Humidity': 46,
#   'Cloudiness': 75,
#   'Wind Speed': 16.11,
#   'Date': '2021-04-12 18:02:05',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kamaishi',
#   'Country': 'JP',
#   'Lat': 39.2667,
#   'Lng': 141.8833,
#   'Max Temp': 53.29,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 17.9,
#   'Date': '2021-04-12 18:05:35',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lannion',
#   'Country': 'FR',
#   'Lat': 48.75,
#   'Lng': -3.4167,
#   'Max Temp': 48.2,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:05:36',
#   'Current Description': 'clear sky'},
#  {'City': 'Okakarara',
#   'Country': 'NA',
#   'Lat': -20.5833,
#   'Lng': 17.4333,
#   'Max Temp': 67.33,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 6.42,
#   'Date': '2021-04-12 18:05:37',
#   'Current Description': 'clear sky'},
#  {'City': 'Kuah',
#   'Country': 'MY',
#   'Lat': 6.3265,
#   'Lng': 99.8432,
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Date': '2021-04-12 18:05:37',
#   'Current Description': 'few clouds'},
#  {'City': 'Cardston',
#   'Country': 'CA',
#   'Lat': 49.2,
#   'Lng': -113.3019,
#   'Max Temp': 32,
#   'Humidity': 59,
#   'Cloudiness': 77,
#   'Wind Speed': 6.91,
#   'Date': '2021-04-12 18:05:38',
#   'Current Description': 'broken clouds'},
#  {'City': 'Boa Vista',
#   'Country': 'BR',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 89.6,
#   'Humidity': 55,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Date': '2021-04-12 18:05:39',
#   'Current Description': 'broken clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                       City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Barrow      US  71.2906 -156.7887    -11.20        70
# 1                Busselton      AU -33.6500  115.3333     51.01        85
# 2  Puerto Baquerizo Moreno      EC  -0.9000  -89.6000     84.20        70
# 3              Port Alfred      ZA -33.5906   26.8910     71.20        92
# 4                Hay River      CA  60.8156 -115.7999     19.40        45
# 5                   Hobart      AU -42.8794  147.3294     46.99        93
# 6                  Rikitea      PF -23.1203 -134.9692     78.26        70
# 7                Tilichiki      RU  60.4667  166.1000    -11.63        94
# 8                   Moerai      PF -22.4333 -151.3333     79.45        79
# 9                  Kavieng      PG  -2.5744  150.7967     78.30        81
#
#    Cloudiness  Wind Speed                 Date Current Description
# 0          20       13.80  2021-04-12 18:01:02          few clouds
# 1          96        1.01  2021-04-12 18:01:03     overcast clouds
# 2          20        5.75  2021-04-12 18:01:03          few clouds
# 3          96       12.80  2021-04-12 18:01:03     overcast clouds
# 4          29       16.11  2021-04-12 18:01:04    scattered clouds
# 5          34        5.75  2021-04-12 17:58:02    scattered clouds
# 6          13       10.36  2021-04-12 18:01:05          few clouds
# 7          27        8.39  2021-04-12 18:01:05    scattered clouds
# 8          96       15.52  2021-04-12 18:01:05       moderate rain
# 9         100       12.64  2021-04-12 18:01:06          light rain

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
